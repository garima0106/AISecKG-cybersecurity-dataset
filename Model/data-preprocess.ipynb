# %%
import pandas as pd
import csv
import os
import numpy as np
import nltk
import re

# %%
from nltk.tokenize import word_tokenize

# %%
path=os.getcwd()
path
# Out:
# '/Users/garima/AISecKG-cybersecurity-dataset/Model'

# %%
annotatedata = pd.read_csv(path + '/annotated_data_BI.csv')

# %%
annotatedata.head()
# Out:
#                                             sentence  \
# 0                  Attacks can damage public domain.
# 1                      IDS means Intrusion Detection
# 2              Snort is used for Intrusion Detection
# 3                  Snort can detect network attacks.
# 4  Snort can also be used as a simple packet logger.
#
#                                               entity
# 0             B-attack can damage B-system I-system.
# 1               B-tool means B-technique I-technique
# 2         B-tool is used for B-technique I-technique
# 3               B-tool can detect B-attack I-attack.
# 4  B-tool can also be used as a simple B-tool I-t...

# %%
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

# %%
for ele in annotatedata['sentence']:
    if ele in punc:
        annotatedata['sentence'] = annotatedata['sentence'].replace(ele, "")

# %%
regex1 = re.compile('B-')
regex2 = re.compile('I-')

# %%
annotatedata.head()
# Out:
#                                             sentence  \
# 0                  Attacks can damage public domain.
# 1                      IDS means Intrusion Detection
# 2              Snort is used for Intrusion Detection
# 3                  Snort can detect network attacks.
# 4  Snort can also be used as a simple packet logger.
#
#                                               entity
# 0             B-attack can damage B-system I-system.
# 1               B-tool means B-technique I-technique
# 2         B-tool is used for B-technique I-technique
# 3               B-tool can detect B-attack I-attack.
# 4  B-tool can also be used as a simple B-tool I-t...

# %%
df2=pd.DataFrame(columns=['tag'])

# %%
for row in annotatedata['entity']:
    for word in row.split():
        res1 = regex1.search(word)
        res2= regex2.search(word)
        if res1==None and res2==None:
            row=row.replace(word,'O')
    print(row)
    df2 = df2.append(pd.DataFrame([row], columns=['tag']))
# Out:
# B-attack O O B-system I-system.
# B-tool O B-technique I-technique
# B-tool O O O B-technique I-technique
# B-tool O O B-attack I-attack.
# B-tool O O O O O O O B-tool I-tool.
# B-tool O O O O B-data
# B-tool O O O O B-feature I-feature.
# B-tool O O B-technique I-technique
# B-tool O B-technique O O O B-attack
# B-tool O O B-data O B-function I-function
# B-function I-function O O O O O B-feature
# B-function I-function O O O
# B-tool O B-feature B-feature B-feature
# B-tool O O B-feature B-feature
# B-tool O O O B-data I-data
# B-tool O O B-tool I-tool
# B-tool I-tool O O B-data
# B-tool I-tool O O O B-feature
# B-tool I-tool O B-data B-feature I-feature
# B-tool I-tool O O B-vulnerability I-vulnerability
# B-tool O O B-tool
# B-tool O B-vulnerability I-vulnerability
# B-tool O B-vulnerability I-vulnerability
# B-tool  O O B-data I-data
# B-tool O B-tool I-tool
# B-tool I-tool B-technique B-attack O B-data
# B-tool I-tool O O B-function
# B-tool O B-tool I-tool I-tool
# B-tool O B-tool I-tool
# B-tool I-tool O B-feature B-feature
# B-tool I-tool O B-feature
# B-tool O O B-feature I-feature
# B-tool O B-technique O B-feature
# B-tool O B-technique O B-feature
# B-feature O B-data I-data
# B-tool B-technique B-data I-data
# B-tool O B-tool I-tool
# O B-tool I-tool O B-data O B-data
# B-tool O O B-data I-data
# B-tool O O B-tool
# B-tool O O B-data I-data
# B-Ool I-Ool O O O B-data I-data
# B-function I-function O O O B-function I-function
# B-function I-function O O O B-data I-data
# B-data I-data O O O O B-data I-data
# B-data I-data O O O O B-system I-system
# B-data I-data O O O B-system I-system
# B-function I-function O O O B-feature I-feature
# B-feature I-feature O O B-data
# B-function I-function O O O B-feature I-feature I-feature
# B-system O O O B-system I-system I-system
# B-feature I-feature O O B-system
# B-Ool O O B-technique B-system
# B-tool O O B-function
# B-feature O O B-function
# B-attack I-attack O B-vulnerability B-data I-data I-data
# B-tool O O B-feature I-feature B-tool
# B-tool O O O B-technique I-technique
# B-tool O O O B-technique I-technique
# B-tool O B-vulnerability B-app O O B-system I-system O O O O B-data O O O B-technique O B-technique I-technique.
# O B-tool O O O B-data O  B-technique I-technique O  B-function
# O B-tool O O O O B-data O O B-attack
# B-tool O O B-feature I-feature O O O O O O O O O O O B-technique I-technique B-tool O O O
# B-tool  O O O O O O B-tool O O B-securityTeam I-securityTeam O B-function O B-system
# O B-function O O B-system I-system O O B-system O O B-techniqueI-technique O B-technique I-technique O B-technique I-technique O O B-technique I-technique O
# O O B-tool O
# B-tool O O B-technique I-technique B-tool O O B-data I-data O O O O B-system O O O B-system O O B-data O O B-app O B-system I-system O O O
# O O O O O O O O B-tool I-tool O B-tool I-tool Ore Olso OvOilOble)
# O O O O O O B-system I-system O O B-system, B-system I-system, O B-system
# B-tool O O O B-system I-system I-system O O B-function O thousOs O B-system I-system
# O B-Ool O O O O O O B-technique I-technique
# B-tool O B-dOtO O O B-feOture B-feOture O O O O O O B-feOture O O O O O B-feOture B-Opp O O B-OttOcker I-OttOcker.
# O B-system O O O O B-system I-system, B-feOture I-feOture, Ond O B-system O O B-system I-system.
# B-vulnerObility, B-function O O B-system O O O B-technique O O B-OttOcker O O O B-OttOck O B-system
# O O O O B-tool O O O O O O B-technique
# O O O O O O B-data O O B-feature B-feature O Or B-system, O O B-feature O On O B-functiO
# O O B-securityTeOm O O O O B-feOture O O O O O B-feOture I-feOture O O B-OttOcker I-OttOcker
# O B-tool O B-dOtO O O B-system O O O
# O O O O O O O O O B-system I-system Ond B-feOture I-feOture Ond O O B-system O O B-system I-system
# O O O O vOluOble B-tool O ongoOg B-technique I-technique Ond O crOicOl pOrt O B-technique
# B-Ool O O O O O B-Ool I-Ool, O O O B-technique O On O B-vulnerability I-vulnerability.
# O B-Ool O O O O vOluOble B-Ool O B-user O O O B-system Ond B-system I-system
# O B-Ool O B-technique O O B-system I-system, O O O O B-feOture O B-system  O B-system, O O O O B-OttOcker B-technique O B-OttOck O B-system
# B-OttOck O O B-system O O O O O O O O identifyOg B-vulnerObility I-vulnerObility
# B-Ool O O O O O O O O B-Ool O O O O O  B-securOyTeam I-securOyTeam O oOr B-function
# B-Ool O O O O O O O rOnge O O B-Ool O O B-function, rOther thOn O O O O O sepOrOte Ond dOcrete B-technique I-technique B-Ool
#  O O B-Ool, O O O O O O B-Ool I-Ool I-Ool
# O O B-user O O B-function O B-feature O O O O O O O O B-technique I-technique.
# B-technique I-technique I-technique I-technique I-technique
# O O O O B-technique B-system B-feature I-feature
# B-technique I-technique I-technique O O B-technique I-technique
# O O B-feOture O B-feOture, O B-system I-system O O B-feOture B-technique I-technique I-technique, Ond O B-Ool I-Ool immediOtely O O B-feOture O Ovoid B-OttOck.
# O O B-feature O O B-feature O B-function O B-system B-feature I-feature O O B-tool I-tool I-tool
# O B-technique I-technique O O O O
# O O O B-technique I-technique I-technique O O B-vulnerability B-feature
# B-function B-feature O O O B-feature beOe B-function B-feature
# B-feature I-feature B-feature O B-data I-data
# O B-feOture I-feOture O B-feOtureO B-system O B-function O O B-feOtureO O B-dOtO I-dOtO O O On B-dOtO I-dOtO I-dOtO I-dOtO.
# O B-vulnerability, O B-feature I-feature O O B-function
# B-technique I-technique O O O O O B-feature I-feature O B-feature.
# O B-feOture O O B-feOture O O B-feOture I-feOture O B-feOture Ond O B-feOture O On B-feOture B-dOtO I-dOtO O O B-feOture O B-feOture, thO O O B-technique cOn O O B-feOture I-feOture.
# O O O O B-feature B-attack I-attack O O B-feature I-feature I-feature  O B-vulnerabilOy I-vulnerabilOy I-vulnerabilOy.
# O O O O O O O B-system O B-feature I-feature I-feature O O O O B-data O O Oing O
# B-system O B-system I-system, O O O O O B-feature I-feature, O O O O B-feature O B-technique B-system B-system  O
# O B-technique I-technique O O B-dOtO I-dOtO O B-feOture I-feOture O O O O B-feOture I-feOture O B-feOture.
# O O B-system I-system O O B-data I-data I-data I-data, O B-feature I-feature O B-feature. OOrwOe, O B-feature I-feature O O O O B-feature.
# B-technique I-technique O O O O O O B-feature I-feature
# O B-technique I-technique O O O B-feature O O O O O
# B-feature O B-feature I-feature O B-function O B-feature, O B-Ool O B-feature I-feature
# B-feature I-feature O O O O B-data I-data I-data I-data. O mOy B-system B-technique I-technique B-data I-data I-data I-data O B-feature O O
# O O O O B-technique I-technique O B-feOure I-feOure, O B-feOure I-feOure O B-technique O B-system O O
# B-technique O B-feature O O O O O O B-technique O O O B-feature I-feature
# O B-feature I-feature O O B-technique I-technique B-technique
# B-technique O B-feature I-feature I-feature
# O B-feature I-feature O O B-system I-system
# O O (B-feature) O B-feature I-feature, B-tool O O O O B-technique O O O B-system.
# B-technique I-technique O O O O B-technique I-technique.
# O O O O B-system I-system  B-function I-function, O B-tool I-tool O B-data I-data I-data O B-technique O B-feature.
# O B-technique O O O O O B-technique I-technique O O O O B-feOture O B-feOture I-feOture I-feOture.
# O B-tool I-tool O O B-dOtO I-dOtO.
# O O B-feature I-feature O B-feature, O O B-feature wOh O B-data I-data
# O B-tool B-system B-feature O O B-data I-data, B-feature O B-feature O O B-technique O O
# O O B-feature O B-feature O B-feature, O B-system O O B-feature O O B-data I-data.
# O O O O O B-technique O O B-attack O O B-system I-system
# B-technique I-technique O O O O O O B-feOture O O B-function O B-feOture
# O O O O B-feature O O O B-feature O B-technique B-feature I-feature
# B-technique I-technique O O O O O O O B-technique I-technique, O B-technique  I-technique
# B-OttOcker O O B-feOture I-feOture Ofter B-feOture On B-feOture I-feOture
# O O B-feature O O B-feature; O O B-system O O B-function O B-feature
# O O B-vulnerObility O O B-technique I-technique I-technique I-technique
# O O B-feOture I-feOture O B-feOture, O B-system O O O B-feOture O O
# B-attack I-attack O O B-attack B-attack I-attack O O B-system O B-feature
# B-technique I-technique O O B-technique I-technique, O O B-technique I-technique, O B-function O B-dOtO I-dOtO I-dOtO insteOd.
# O O O O O O O O B-data I-data O O O O O B-feature O O O B-technique I-technique cO O B-feature I-feature Od B-feature, O O O O O O O O Ome B-tool B-function Od oOr O
# B-technique I-technique O O O B-feature O B-feature O O
# O O O O O O O B-technique O O exOtence O O B-Ool Ond O B-function.
# O B-technique I-technique O O B-feOture I-feOture (B-dOtO O O I-dOtO I-dOtO O O O O sophisticOted B-feOture B-tool O O
# B-technique I-technique O O B-dOtO O O B-dOtO I-dOtO I-dOtO I-dOtO O eOch B-feOture I-feOture
# O O B-attacker O O O O B-technique I-technique B-system
# O O B-OttOcker O O O O O B-feOture I-feOture O B-Ool O B-system O Ollow inO O B-system O O O B-feOture O O B-Ool Ollow B-feOture I-feOture B-feOture
# O O B-feOture O O B-dOtO I-dOtO I-dOtO I-dOtO O O B-tool O O O B-feOture I-feOture O B-feOture, meOing O O B-technique I-technique O B-feOture O B-feOture.
# O O B-technique I-technique O O O O B-feature I-feature I-feature O O O O
# O O O O O vOlid B-dOtO, Ond O B-system  O O O whOt O O O thO.
# B-system I-system I-system O O O O O B-technique O O B-technique I-technique O O O O
# O O B-system I-system O O O B-Ool, O cOn O O wOy O O O
# B-technique I-technique O O O O B-technique I-technique, O O O O B-feature O O B-feature I-feature O O O O
# B-system I-system O B-feature O O O O O O Oir B-feature I-feature O O
# O O O O O O O O O B-feOture O O O O O O B-dOtO
# O B-technique O O O O O B-feature, B-feature, O B-feature I-feature O O B-feature I-feature.
# B-technique I-technique O O O O B-technique O O B-system O O B-function (B-function I-function I-function) B-apps.
# B-functiO, O O B-functiO I-functiO O O O O O B-system  O O cOditiOs, O O O dOngerous B-feOture.
# O B-Opp I-Opp O O O O O B-feOture, O O O O O O O normOl B-technique O Oes O O Oning B-functiO
# O B-technique O B-technique O B-feOture O B-feOture O O B-system O B-functiO O O O B-functiO B-feOture Ond B-feOture O B-functiO O O
# O O O bOd ideO O B-function O O O B-technique O Oten O O O O Ond O O hOve O B-feOture B-function.
# B-technique B-app I-app O O O B-feature B-feature I-feature O O B-system O O B-functiO I-functiO I-functiO.
# O O O O O B-function B-function O B-feOure O O B-feOure Od identOies O O B-function B-function
# B-technique I-technique O O O B-technique I-technique O O B-technique B-dOtO Ore O O On B-system I-system
# O O O O O O O O oOr B-system, O O O O O O O O O O B-feature.
# O O O O B-feature I-feature O O B-system I-system O O B-feature I-feature O O
# O O O O O O O O O B-tool sOce O O O O O O O B-OttOck I-OttOck.
# B-technique O B-system B-feature I-feature O O O B-vulnerabilOy O B-data I-data O O B-system O O O O O O B-feature O O B-system.
# O O O B-feature I-feature, O B-system reactiO O O O O O O B-system B-feature I-feature O O O
# B-technique O B-system B-feature I-feature O O B-system B-feature I-feature O On O O O thO O B-feature I-feature
# B-tool O O B-tool I-tool I-tool,
# O O O O O digOOl librOry O B-function I-function thOt O enhOnce O B-feOture B-tool B-feOture O O O O O O trOdOionOl B-tool B-feOture
# O O O O O O O O B-functiO, O O O O O O O O B-Ool B-feature B-functiO I-functiO.
# O O O O O O O O B-function O O O O O O O O B-Ool I-Ool I-Ool.
# O O O O O O O O B-feature B-tool O O O O B-system  O O B-technique O O O Oy O B-functiO.
# B-function I-function O O O B-function O O O O O O B-technique O O B-tool O O O B-data O O B-system I-system.
# O O B-tool B-feature B-technique O O O B-system B-technique, B-technique, B-technique I-technique, O B-technique I-technique, O O perfOm O B-function I-function
# B-functiO I-functiO O O pOrticulOr O O B-functiO I-functiO thOt O B-functiO OgOinst B-feOture O O B-system I-system.
# O O B-function I-function I-function, O O O O O B-function O B-system I-system.
# B-function I-function O B-function O O O B-technique I-technique O O O O O O O B-function, B-function, O O O O O
# O O O O O B-feature B-function I-function, O O O O O O O O O O O O Om O O O.
# BOfunction IOfunction O O O O BOtechnique  O BOfeature IOfeature BOfunction
# BOfunction IOfunction  O BOtechnique IOtechnique BOfunction O O BOfeature O O BOsystem O
# BOfunction IOfunction O O O BOfunction O perOming BOattack IOattack IOattack O O BOfeature IOfeature
# BOfunction IOfunction O O O O BOfunction IOfunction, O OsC O BOfeature
# BOfunction IOfunction  O  BOfunction O O BOtechnique IOtechnique, BOtechnique IOtechnique O BOtechnique IOtechnique
# BOfunction IOfunction   O BOattack IOattack IOattack IOattack BOfunction O O BOfunction O BOfunction BOattack O BOattack
# BOfunctiO IOfunctiO O  O O O BOtechnique IOtechnique O O BOvulnerability
# BOfunctiO IOfunctiO O  BOfunctiO O O O BOapp IOapp IOapp O BOdata
# BOfunction IOfunction O O O BOfunction BOattack IOattack O BOapp, BOapp O BOsystem
# BOfunction IOfunction O  O O BOfeOture BOfunction O O O O O BOfeOture IOfeOture
# BOfunction IOfunction O BOtechnique IOtechnique O BOtechnique BOfunction
# BOfunction IOfunction O  BOfeature O BOfeature O BOfeature BOfunction
# BOfunction IOfunction O BOsystem O BOapp O BOtechnique IOtechnique BOfunction
# BOfunction IOfunction O O BOtool BOvulnerability O O BOtechnique IOtechnique O BOtechnique BOfunction
# O O O O B-feature O B-technique O B-system I-system I-system.
# B-Ool O O O O B-function B-function O B-function, O O O O O B-function O O O O O O O O
# O O O O O O B-function O O B-function O O O B-feature, O O O O B-feature
# O O O O O O O O O O B-function O O O O O
# O O O O O O B-function I-function O O B-function I-function B-feature B-technique O B-feature I-feature, B-function, O B-technique  I-technique,
# B-Ool O O O O O O O Or O B-function O B-function O B-function B-feature O Or B-system I-system.
# B-featureO B-tool I-tool I-tool  I-tool O O B-tool I-tool I-tool I-tool O O O O O O B-function O O Or B-technique I-technique O
# O O O O O B-system, O O O O O B-technique I-technique I-technique I-technique O O O O O strOg B-technique I-technique O O B-system.
# B-technique I-technique I-technique O B-technique I-technique, O O B-tool O O O O O
# B-system O B-technique B-system O O O O B-technique I-technique O O B-feature, O
# O O O O O O O B-technique.
# O O OdvOed O O O O B-system O O O certOin O O
# O O O O B-feature, O B-attacker O O O O O O O O O O B-attack O O lOg O O B-technique O B-vulnerability.
# O O B-technique O O O B-system, O O O B-technique O O B-system I-system.
# O O O O O B-technique I-technique I-technique I-technique O B-technique I-technique O O O B-technique O B-securityTeam.
# B-technique O O O O O O B-attacker.
# O O O O O O B-feOture B-tool B-feOture O B-tool O B-technique I-technique, O O O O B-OttOcker I-OttOcker.
# O O O O O O mOtOke O B-function O B-Ool Ond O B-system.
# O O O O O O O B-vulnerability I-vulnerability O O B-user O O O O
# O B-technique I-technique O O O O O B-function O B-attacker O
# O O O O O B-technique B-tool O O B-technique I-technique O O O O O O
# O B-attacker O O O O O O O O O B-tool B-feature O O O B-system  O O O O B-feature.
# B-tool I-tool O O B-tool O B-tool O O O O B-technique B-function I-function O B-technique I-technique B-tool.
# O O O B-attacker I-attacker O O O O O O
# O O O B-securityTeam O O B-attacker O O O O O O O Oy O O O O B-vulnerability I-vulnerability O B-attacker O
# O O O O O O O O O B-tool O B-tool.
# O O O O O O O  B-securityTeam I-securityTeam
# O O O B-technique I-technique O O O O O B-technique I-technique
# O O O B-technique O O O O B-technique
# O O O O O B-system I-system
# O O O O B-technique O O B-technique O B-function I-function B-system O B-Ool I-Ool.
# O O B-technique, O O O B-technique I-technique I-technique, O O O  B-securityTeOm I-securityTeOm hOs O Occess Ond O O O O  B-securityTeOm I-securityTeOm, OcludOg O O O B-feOture B-function I-function Ond B-function I-function B-system.
# O O O O B-technique O O O O B-feature Osues O B-feature O B-Ool, O O O B-system B-vulnerability O O B-vulnerability I-vulnerability.
# O O O O  B-securityTeam I-securityTeam O O B-app O B-tool B-feature, O B-system I-system I-system.
# O O B-technique I-technique, O  B-securityTeam I-securityTeam O B-technique O O O B-feature O B-feature O B-tool.
# O  B-securityTeam I-securityTeam O O B-technique B-vulnerability O O O O
# BOfeature IOfeature O BOtool BOsystem O O BOfeature, BOfeature, BOfeature,  BOfeature BOfeature, O BOapp O BOsystem, BOtool BOtechnique IOtechnique, O
# B-tool B-system O O B-feature I-feature I-feature, O O O B-attack I-attack, O
# B-vulnerability: O O O B-system B-system B-function O O B-tool
# O  B-securityTeam I-securityTeam O O O B-technique O B-technique I-technique O O B-Ool O B-Ool O O sOp O/or B-technique B-functiO B-attack.
# O O  B-securityTeam I-securityTeam O O B-vulnerability I-vulnerability O O O O O B-system I-system.
# B-technique O O  B-securityTeOm I-securityTeOm O O O O B-technique O bOsed O O O B-feOture, Ond O O chOnges O remediOtiO O B-Ool Ond B-Ool B-functiO O mOximOlly O O B-technique I-technique.
# O O O B-system I-system O O O B-technique O B-tool O B-tool
# O O O B-technique O O O B-technique O B-technique O B-technique O O O B-Ool O B-Ool
# O O O O O B-technique O B-vulnerability I-vulnerability O O B-system I-system, O O O O O B-technique.
# O O  B-securityTeam I-securityTeam O O O O O O O O B-system I-system O O B-tool, B-tool, B-tool I-tool I-tool, B-tool, O
# O O O O O O O B-Ool O O O
# O O O O O O Or O B-Ool O B-function B-function O B-function O B-technique I-technique.
# O O O O B-technique O O O B-system I-system.
# O O O O B-tool O O B-tool, B-tool, B-tool, B-tool, B-tool, O O O B-system I-system.
# B-system I-system (B-system I-system): O O O B-functiO B-app B-Ool O B-Ool O B-feature O B-system I-system O O O B-app O B-Ool B-data I-data.
# O O O O O B-app B-data I-data O B-function I-function B-data O O O B-function:
# O O B-function I-function.
# O O O O O O O O B-feature
# O O O O O B-feOure I-feOure O O O O O B-technique O B-feOure O O Or O O envirOment, O  O B-app O  B-feOure I-feOure
# O O O O O O Or B-feature O  O O O B-system O
# B-system I-system (B-system I-system)
# O O B-system I-system, O O B-vulnerability B-app O O O
# O O O O O O O O O O O O O B-system I-system B-system I-system O O O
# O O lab,B-feature, B-tool, B-tool, O B-tool O O O B-app I-app O B-tool O O O O
# B-feature, B-tool, B-tool I-tool
# O O O O B-function B-attack O O B-Ool.
# O O O O B-function O O O B-vulnerability O O O B-app I-app O B-app
# O O B-app, O B-feature O O B-Ool I-Ool, O B-data, O B-app B-feature, B-technique B-feature B-data, O B-feature I-feature O B-system.
# O O B-technique O B-vulnerability?
# O O O O B-Ool O B-technique O B-vulnerability
# O O B-technique O B-technique I-technique O O O B-functiO I-functiO
# B-technique O B-technique B-tool O B-tool I-tool I-tool
# B-Ool B-system O O O O B-function O B-technique
# O O O O O O B-technique, O O O B-Ool B-function O O O B-function I-function O O O O B-feature
# O O B-technique B-system O O O B-system I-system B-system
# O B-technique B-feature O O B-function I-function
# O O O O O B-function I-function O O O B-technique O
# B-tool O B-tool I-tool O O O O O B-system O B-system I-system.
# O O O O O O B-technique O O O B-system O O O B-system, O O O O O O O B-tool O B-technique O B-technique O B-OttOck.
# O B-Ool O B-technique O B-data O O B-feature O B-feature B-feature O O B-system O O O O O O O O understO O O O O O B-system.
# O O O O O O O B-technique O O O O
# B-technique O O O O B-technique, O O O O O O
# O O O O O B-O I-O O O B-system O O O B-O I-O O O O B-O I-O O O B-O I-O O O O O O B-dOtO I-dOtO I-dOtO I-dOtO.
# O B-data I-data O B-feature B-feature O O B-Ool O O
# B-feature B-system O O B-Ool, O O oOr O O O O B-data O O O B-feature
# O O O O O B-data I-data I-data O B-feature I-feature) O
# O B-data I-data O B-data I-data O O O O B-data I-data, B-tool O B-feature B-technique B-feature B-feature I-feature O B-feature O B-feature O O O O O O
# O B-technique I-technique O B-data I-data O O O B-data I-data I-data O
# O B-feOture O B-feOture O B-feOture, O B-system O O O B-feOture I-feOture O B-feOture O O B-dOtO I-dOtO.
# B-tool O B-feature O B-technique
# O B-tool O O O B-feature O O O O B-data I-data I-data I-data
# O O O B-Ool O O O O B-data I-data O O B-feature.
# O O O B-feature I-feature O O O B-Ool B-technique I-technique O Oten O thO O O B-technique I-technique O O O B-system O B-technique I-technique O O O O B-feature.
# B-feature B-Ool O B-feature B-feature B-data I-data O O B-data I-data I-data) O O O O O O thO, O O O O Oy B-data I-data O
# B-feature O B-data I-data O O O O O O O O O O O O B-feature.
# O B-technique I-technique O B-technique I-technique O O O
# O B-feature B-attack B-data I-data O O O O B-Ool B-technique I-technique), O O B-data I-data O O B-feature B-feature,
# B-Ool O B-feOture O O B-feOture I-feOture O O O O O B-feOture O OppropriOte.
# O O O O B-feature B-tool B-function O O O O B-feature B-tool O O O
# O B-feature B-tool O O O B-feature O O O O O O
# B-feature B-technique I-technique O O O O O
# O O O O O O O O O O O O B-feOture B-Ool B-function cOn cOuse O B-system O O B-feOture O terminOte Oll B-feOture I-feOture pOssing O O
# O O O O O O O O O O O O O B-Ool B-technique O O B-technique O O O O O O B-Ool B-feature: B-feature, B-feature, B-feature, B-feature.
# O O O O O O B-Ool B-system O O Ose O
# B-system O B-feOture I-feOture O O O B-feOture I-feOture O O O B-feOture I-feOture O O B-feOture I-feOture O O O O O B-dOtO I-dOtO I-dOtO I-dOtO
# O O O O O O O O O O O O B-feature B-Ool B-feature O O O B-technique B-feature O O B-Ool.
# O B-feOture I-feOture O B-dOtO I-dOtO O O O B-dOtO I-dOtO I-dOtO. WheOr B-feOture O B-feOture O B-feOture, O B-system O O O B-feOture I-feOture O O O O B-dOtO I-dOtO.
# O O O O O O O O O O O B-feature O B-feature B-Ool B-feature B-system O O O B-technique B-feature O O B-Ool.
# O O O O O O O O O O O O B-technique, O O O O O O O
# O O O O O (B-feOure O B-feOure) B-feOure O O B-system O O O B-system.
# O B-system O O O O B-data I-data O O O O
# O B-system I-system O O O
# O O O B-system O O B-feature I-feature O
# O O B-system I-system O B-Ool O O thOt O B-dOtO I-dOtO O O O B-feOture I-feOture, O O OpOrt.
# O O B-OttOck O O O B-system
# O O O O O O B-feature O O B-tool B-system.
# O O O O B-feature I-feature O O O O O O O O O O
# O B-system O O O O O B-attack I-attack O O O O O O O O
# O O O O B-vulnerability B-feature O O O O O O O O B-tool.
# O O O O O lOt O B-system B-feOture B-technique thOt Ore O O O B-tool Ond O thOt Ore B-feOture.
# B-feature O O O O O O B-feature O O O O O B-feature I-feature O B-feature O.
# O B-feature B-app O O O B-data, O O B-tool O wheOr O B-feature O B-feature O B-feature.
# O O O O O “B-feature  O B-feature” O O O B-technique I-technique?
# O O O B-Ool O O B-technique I-technique
# O O O B-technique O O O furOr B-functiO B-technique I-technique O B-technique I-technique I-technique?
# B-Ool O O O O –B-system  B-feature O O O B-system B-feature O B-data I-data.
# O B-tool I-tool I-tool O O O O O O O B-tool I-tool I-tool.
# O O O B-technique O B-system O O normOl B-tool Ond O B-feOture I-feOture I-feOture.
# O O B-Ool I-Ool O O O O B-system O O B-feature I-feature O B-vulnerability I-vulnerability O B-technique.
# O O O B-tool O B-feature Oy O B-data O O B-feature I-feature O O O O B-technique I-techniqued O O O aB-attack I-attack I-attack.
# B-OttOcker O O O O O O O B-technique I-technique O B-system Ond cOnnot O O O O B-feOture I-feOture.
# B-attacker O O O O O B-feature O O O O O O B-feature I-feature
# B-vulnerability B-data I-data O O O O O B-tool O B-feature O B-attacker O
# O O O B-Ool O O O O O O B-system O B-vulnerability B-data I-data O O O B-feature.
# O O O O O B-data O B-vulnerability O O O O O O “B-technique B-attack I-attack O B-Ool O B-Ool I-Ool I-Ool”.
# O O O B-system B-app B-system, O O O O O O O B-data O O
# O O O O O B-feature, B-feature, B-feature,B-feature, iB-feature O iB-feature, O O O O B-data I-data I-data (B-feature O O O
# O O B-feature O O O O B-functiO O Oly O O B-feature I-feature:
# O O O B-dOtO I-dOtO I-dOtO O O O bOck.
# O O O O O B-featureB-feature I-feature B-technique, O O O O O O O B-feature B-system I-system (O O O O O otherwOe).
# B-attack B-data I-data O B-tool O B-tool O B-tool O O O O O O B-feature I-feature.
# O O O O O B-feature B-securityTeam I-securityTeam O O B-Ool O O O O O O O B-feature O O O O B-feature O O B-data I-data
# O B-attack O
# O O B-technique O O B-technique O O B-data I-data O O oOr B-data O O O B-system.
# O O O O O B-app B-function O O O O O O O O O O Or O O O B-tool B-system.
# O O O B-technique O B-Ool O O O O O O O B-vulnerability B-system) O B-Ool.
# O O B-system I-system O O B-tool B-function, B-tool O O fOster Ond O O OlternOtive O O B-tool O
# O O O O B-technique B-feature B-tool O O O O B-feature B-technique O B-system O O O O O B-function
# O B-technique B-app B-function O O O B-tool O B-function, O O O O O B-function O O O O B-data.
# O O O O O O O O B-technique O O B-Ool (B-Ool).
# O B-tool O B-technique O B-technique O O O O O B-functiO I-functiO,
# O O B-function O B-technique B-feature O O followOg O O
# O B-feature I-feature O B-system I-system, O O O O B-function O O B-system I-system.
# O O O O O B-function O O O O B-Ool O B-function.
# O O O O O B-Ool B-technique O O O B-Ool B-technique B-functiO O O O B-technique O B-functiO I-functiO
# B-Ool O O B-feature I-feature O O O O O O O O O O O
# O O O O B-feOure I-feOure O B-Ool O O O O B-technique O O O wOiting O O O Om.
# O O B-technique O O O O O O O O O O O B-technique.
# O O B-feature I-feature O O O O O waOs O O O B-technique.
# O B-technique O B-system O O B-technique B-system O
# B-feOture I-feOture O O O mOjor O O B-tool I-tool I-tool
# O O O O O O O O B-feature I-feature O B-feature I-feature I-feature O O O O O O B-system.
# O O B-Ool O O O O O O O B-system I-system O O O B-dOO
# O B-tool B-technique O O B-feature I-feature I-feature
# O O B-Ool O O O O O B-dOtO O B-dOtO O O B-feOture, O O typicOl O O O B-dOtO (dependOg O optiOs) B-dOtO I-dOtO O O O O B-feOture I-feOture
# O O O O O O O O O BOeature BOeature IOeature.
# B-technique O O O O B-tool B-data I-data O O B-feature O B-feature B-technique I-technique O B-technique I-technique O B-technique I-technique I-technique) O B-technique I-technique.
# B-feature O O B-technique I-technique O O B-tool I-tool I-tool O O O B-technique
# O O O O O B-system B-feature I-feature O O withB-app I-app
# B-technique O O O O O O
# O O O O lOt O B-system O sepOrOted O commOs.
# O O O O O O O O O O B-technique O O O O O B-system I-system O O O O B-technique O
# B-system B-feature, O B-tool O O O O B-technique I-technique O O O B-system
# O O B-Ool O O O O O O B-system O O O O B-vulnerability B-feature, O B-Ool O O O O B-feature.
# B-tool B-function O O B-system O O O B-vulnerability O O O B-technique.
# O O O O O O O O O O O O B-securityTeam mOd O O B-tool B-feature.
# O B-O I-O O O O O thOt Ollows O B-vulnerObility O B-system B-feOture I-feOture, Os dOcussed O O O O O O obtOOOg OccurOte B-O I-O I-O O
# O O O O O O O O O B-feature I-feature I-feature O O O O  B-system.
# O O B-system I-system O O O B-attack I-attack I-attack
# B-tool O B-function I-function O O O O B-feature B-system.
# O B-function I-function B-technique O O B-technique. O O O B-feOture O O B-technique I-technique O O O B-technique O wOy.
# O B-technique O O O O B-system I-system B-function O O B-system O B-tool.
# O O O O O O O B-feature O O O O O dOable O B-function I-function I-function
# O O O O O mOe O O B-system I-system O O B-system I-system O O B-Ool, O O B-function I-function O O B-system  O Om.
# O B-technique O O O O O O O O O O O O O O O O B-technique.
# O O O O B-Ool I-Ool  I-Ool O B-function O O O O B-Otack,
# O O O O B-app, O B-feature O O B-Ool I-Ool, O B-data, O B-app B-feature, B-technique B-feature B-data, O B-feature I-feature O B-system
# O O O O B-tool I-tool  I-tool B-tool I-tool O B-technique I-technique
# O O O O O O B-Ool O B-technique O B-technique B-vulnerability I-vulnerability, O O B-system I-system.
# O B-Ool I-Ool O O B-vulnerability B-data I-data O B-technique I-technique
# O B-Ool I-Ool O O O B-vulnerObility B-system, O B-system.
# O B-tool O O O B-technique I-technique O thOt O B-dOtO Obout B-vulnerObility I-vulnerObility Ond Oids O B-technique I-technique Ond B-technique I-technique I-technique.
# O O B-technique O B-app O O
# O O O O O B-feOture B-tool I-tool, O B-tool O O Ond O B-function I-function OgOinst O B-system I-system I-system.
# O B-tool O O B-technique O B-technique B-tool, O O O O O O O B-tool I-tool.
# B-tool O O O O B-system I-system I-system I-system
# O O O O O O B-tool O B-feature, B-tool, O O O B-system I-system.
# O B-tool I-tool O O O O O O O B-function, B-data, B-function (B-tool B-function), B-tool, B-function, O O B-app I-app.
# O B-tool I-tool O O O O B-data O B-tool O B-tool I-tool.
# B-tool I-tool O O O O B-technique I-technique, B-technique I-technique, B-technique I-technique, O B-technique I-technique I-technique.
# B-tool O O O O B-user I-user O O O O O O O O O O O O O B-function, B-tool, B-tool, O B-function.
# O B-tool O O O O B-data gaOring B-tool O O O B-function, O O O O O Orself.
# O B-Ool O O B-app I-app O O O O O O B-app, O O O O O O O B-function I-function O O B-function I-function O O B-function I-function.
# O B-app I-app I-app O O O B-tool O B-app, O O O O O thO O
# O O O O B-system I-system B-feature I-feature, O O O O B-tool I-tool O B-tool O O O B-tool icO O O B-app.
# O O O O B-app I-app O B-app I-app O
# O O O O O B-function O O O B-Ool O B-function O O B-system
# O B-Ool O O B-function, O O O O O O O B-function B-Ool:
# O B-function I-function O B-Ool O O O O O pOrticulOr B-function Ond chOnges O O O O B-Ool O thOt pOrticulOr B-function
# O B-functiO O O O O O O O O B-tool I-tool
# O O O O O O O B-Ool I-Ool O O O B-function O B-vulnerability.
# O O O B-dOtO O O B-technique, O O O B-function I-function, O O O O O B-system.
# O O O O O O B-function O O O O O O B-Ool, O O O O B-function I-function.
# O B-function I-function O O O O O O B-Ool O O O O
# O O O O B-function I-function O O O O anoOr B-Ool B-function.
# O B-function I-function O O O B-Ool O O O O O O O B-system I-system.
# O B-function I-function O O O O O O B-function Ond O O O O Ot O B-tool.
# O O O B-function O O O cO O O B-function I-function O O O lOt O B-function I-function.
# O O B-function O O O O B-function I-function, O cO O B-dOtO O O B-feOture, B-Opp, B-user, O B-system Od O O O O O O B-function I-function.
# O O O O B-data I-functiO O O B-functiO O B-vulnerability
# B-tool O O O O B-function, O O O O O O
# O O O O B-function, O B-function I-function O O O O O O O O O
# O O O O O O B-function I-function O O Osuing O B-function B-function O O O seOrch O O exOmple, flOsh O seOrch O B-function relOted O B-Ool I-Ool.
# O O O B-function I-function, B-tool O O O O O O O O O B-function B-feature O B-feature
# O O O O O O O B-function relOted O O Oten B-vulnerObility B-Opp I-Opp I-Opp.
# O O O O O B-vulnerability I-vulnerability  I-vulnerability  I-vulnerability  I-vulnerability  I-vulnerability  I-vulnerability  I-vulnerability, O O O O O  B-attacker I-attacker B-attack I-attack.
# O O O O B-function I-function O O O O seOrch O O O B-Or, On B-feOture I-feOture, O O B-Opp.
# O O O O O O O O sO O B-feOure I-feOure O O Om O O B-function I-function.
# O O O O O O O O sO O B-dOa, B-system, B-feOure, O B-technique O
# O B-function I-function I-function O O O O O B-feature O O B-function O O O O B-tool I-tool O O B-function O
# O B-vulnerObility I-vulnerObility O O totOl O O O O O O O Ore O
# O O O B-function I-function I-function  O O O O O B-system  O O B-function O
# O O B-system O O O O B-system  O O O B-function.
# O O B-function I-function O O O O B-feature O O O O O O O O Os
# O O O B-function I-function I-function O O O O O O B-feature O B-feature O O O O
# O O O B-function O O O O B-function I-function O O O O O O O
# O O O O B-function I-function I-function, O B-tool O O O O O compOtible B-dOtO O O B-function.
# O O B-vulnerObilOy I-vulnerObilOy O O O O quOe O O compOtible B-dOtO
# O O O certOin B-dOtO, O O O O O B-function I-function O O O B-dOtO nOme
# O B-function I-function I-function O O O O O B-system I-system O Ore B-vulnerObility O O O B-function.
# O O O O B-function, O O O O O O O B-vulnerability I-vulnerability
# O B-function B-system O B-system O B-system B-system I-system.
# O O O O O O B-data I-function O O O B-data O O B-function O B-system.
# O O O B-system, O cOn O O B-function I-function O O O B-feOture I-feOture
# O O O B-system, O O O B-dOtO O O O O O OcOuse O B-dOtO O O O O Ore compOtible O O B-system  (B-system)
# O O O B-function I-function I-function, O O O O O B-feOure I-feOure O O B-function.
# O O B-function I-function, O O O B-feature B-feature O O O O O O O B-feature O
# O B-function I-function I-function O O O O O B-function I-function
# O B-function O O O B-function I-function O O O O O O O O O B-function I-function O O O bypOss O B-Ool O B-Ool B-feOture O O B-function I-function.
# O B-function I-function O O O B-system I-system O O O
# O O O B-function I-function, O O B-function I-function, O O O nOme O O B-function I-function.
# O O B-function O O O B-function I-function O O O O O B-function I-function.
# O B-function I-function I-function O O O O OvOilOble B-technique I-technique.
# O O B-technique B-feature, O O B-function I-function, O O O B-technique B-feature O O O O
# O O O O O O O O O O B-function, O O B-dOtO Ond B-feOture B-feOture O O B-function I-function, B-technique O, Ond B-function, O B-function O reOdy O O O
# O B-function O O O O O B-function: B-function O B-function.
# O O B-function O B-function O O B-tool O O B-function O O
# B-system I-system O O O B-vulnerObility B-system I-system O Od O O O O B-system I-system O Oy B-system  O O B-system, B-system I-system, Od B-system I-system.
# O O O O O B-system I-system O O O O B-technique I-technique O B-technique I-technique.
# B-technique I-technique O O O B-technique O B-system  O B-system fO B-feOture B-feOture Ond B-feOture I-feOture.
# B-technique O O O O O O B-app O O O B-feature.
# O O B-feature O B-system I-system O B-feature
# O O O O O O B-vulnerability B-system, O O O O B-function I-function O determOe O B-feature I-feature.
# O O O O B-Ool O O B-system I-system I-system  O B-technique O rOnge O B-feOture I-feOture O O B-system I-system.
# O O O O O B-function O O O B-Ool B-technique I-technique O B-app O B-technique I-technique
# O B-tool B-technique I-technique O B-technique I-technique O O O O B-feOture I-feOture, O B-Opp, O O B-feOture O O B-system I-system
# O B-system I-system O O B-system I-system I-system I-system O O B-system I-system.
# O O O O O B-system O O O B-Opp I-Opp O B-tool, O B-Opp I-Opp, O B-system I-system I-system, O B-system I-system, Od O O B-Opp.
# O O O O B-app O O O B-feature O O
# B-system I-system O O B-vulnerability.
# O O O O O O O O O O O O B-app, O B-vulnerability, B-attack, O
# O B-vulnerability I-vulnerability, O  B-securityTeam I-securityTeam O O B-user O O O O B-system O O B-user O O O B-system.
# O O O B-vulnerability I-vulnerability O O O O O O B-system O O B-technique I-technique I-technique.
# O O B-feature O O O O O B-securityTeam I-securityTeam, O O O O O B-technique I-technique O O B-feature.
# O O O O O B-vulnerObility I-vulnerObility O O B-system I-system
# O B-functiO O B-feature I-feature O O O B-system I-system, O O O O O O B-functiO I-functiO
# B-O O O B-system O O O O B-system B-function I-function.
# O B-feOture I-feOture O O B-feOture O O B-system O B-system I-system thOt O O O B-technique O O B-feOture.
# O B-feOture O B-feOture O O O O O B-feOture, O OrefOe O O O O B-feOture I-feOture.
# O O O B-feature I-feature O O O O O B-system I-system O O O O O B-system I-system I-system O B-system I-system I-system
# O B-feature O B-feature I-feature, O B-feature I-feature O O O B-system I-system, O O O O O B-technique I-technique O
# O O O O O O O B-system B-system Ond O O O B-feOture I-feOture O O B-system I-system B-system I-system
# O O O O O B-feOture, Ond O cOn O O
# O O O O O O B-function O B-function O O B-Or O O B-system O
# B-tool O O O O B-system I-system.
# O O O O B-function B-system O B-system  B-system  O O O O B-Ool.
# O O O O O B-function O B-system, B-O, O Ond B-O
# O O O O Ot O O O B-Ool Ond O O O B-system I-system
# O O O O O O O O B-tool.
# O O B-tool B-tool, O O gaOr B-data, O O B-system B-feature I-feature, B-system I-system, B-feature B-feature, O B-vulnerability.
# B-Ool O O O O B-Ool O O O B-Ool.
# B-Ool B-feature O O O O O O B-feature O O O O B-data O O O
# O O O O O O O B-technique O O O B-tool, B-technique I-technique I-technique, B-function I-function, O O B-technique I-technique I-technique.
# O O O O O B-app O O O O B-system
# O O O O B-Ool B-function I-function I-function O O O B-vulnerability
# O O O O B-Ool O O B-vulnerabilOy I-vulnerabilOy O B-vulnerabilOy O O B-system B-app I-app, O O O O B-functiO O B-attack O B-system
# O O O B-vulnerability I-vulnerability O Or B-system O B-Ool B-functiO O O O B-functiO O O
# O O O O O O O O B-vulnerability O O O O B-system I-system, O O O B-functiO.
# O O O B-Ool O O B-OttOck O O mOy O O O B-OttOck O B-system B-feOture.
# O O O B-function, O B-tool O
# O O B-tool I-tool O O B-attack) O establOhed, On O O O B-function B-function O O B-system I-system.
# B-tool O O O O O O O O O B-system O O O O O B-data O O O determOe O O O O B-data O O gettOg O O O O O O O O workOg O Or B-system I-system.
# B-tool O O O O B-data I-data. O O O B-tool
# O O O O O O O O O O Od
# O O B-feature O O B-technique O O O O O B-data
# O B-technique I-technique O O B-technique O B-vulnerability
# O O B-attack O O B-technique I-technique
# O B-system O O O O B-feature O B-data, B-data ,B-data, O
# O B-data I-data O O O B-data I-data O O B-data O B-functiO B-data I-data O B-system B-system.
# O B-data O B-function O B-function.
# O O O O O O B-Ool O O O O O O O O B-Ool O O workOg B-Ool I-Ool, O O O O B-data I-data O B-system I-system I-system.
#
# O B-function B-tool (B-dOtO O O O O B-dOtO O B-tool B-function O O O O O B-feOture B-dOtO), O B-function consOts O O B-feOture, O B-feOture I-feOture O On B-feOture I-feOture.
# O O B-feature O O O O O mOe O O O
# O B-feOture I-feOture O O pOttern O fOcilities Ond O O O O O B-feOture.
# O B-feOture I-feOture O O O O O O O B-system Ond O B-feOture, sepOrOted O O O
# O B-feature O O O O O O B-featureO B-featureO B-featureO B-toolO B-appO B-system O B-appO B-featureO B-featureO B-technique(same O B-feature)O B-toolO B-userO B-feature O B-feature O B-feature.
# O O B-technique O O O O O O O O O O O O O thereOe O O O O O B-app.
# O O O O O O O O B-data O
# O B-system O O B-system O O O B-data, O O B-app I-app B-function O O B-app B-system (B-app I-app) O Oy B-function O B-tool.
# O B-feature O O O O O O O OcendOg O B-technique, B-data, B-data, B-data, B-feature O O B-data), B-feature, B-dataO O B-data), B-feature, B-data, B-feature, B-featureO O B-feature).
# O O B-data, B-feature O B-feature O O O O O O O O
# O B-feature O O B-feature O O B-data
# O B-feOture O O O O O O Oction O O O O sepOrOtor.
# O O O O O B-technique I-technique O O B-data B-system.
# O O O O O O B-functiO O O B-feOture O O O B-system I-system O O sepOrOte B-dOtO I-dOtO Oside B-feOture O O nOme O B-dOtO
# B-function O O B-app O B-data O O B-data I-data
# O O O B-dOtO B-dOtO O O B-feOture B-user O Oir B-system
# B-function O O B-tool B-data O B-data
# B-technique I-technique O O B-dOtO O O O O O B-system O B-dOtO O O B-system O B-dOtO O O O O O B-function O O B-dOtO I-dOtO.
# O O O O O B-dOtO lOten O O B-system B-feOture I-feOture O locOlly generOted B-dOtO I-dOtO.
# O O O O B-data O O O O B-Ool O O O B-app I-app I-app.
# O O O O B-data O O O O B-app B-feature O B-data Owarded O oOr B-system.
# O O O O mOsing B-data O O O B-feature B-data O O O O O B-feature I-feature Onot O O
# O B-app O O O O O O B-data I-data.
# O O O O O B-dOtO O O O O O O O O O
# O O O B-Opp B-dOtO O O B-system I-system O B-dOtO I-dOtO
# O O O B-app O B-system O B-data
# O O O B-data O O O B-system
# O O B-data O O O
# O O O O B-app B-function O O O O O O appropriOe O
# O O B-function B-dOtO O B-function O B-Opp B-dOtO O O O B-dOtO I-dOtO?
# O O B-app B-data O O B-function inO B-feature
# O O O O O B-function O O B-tool B-data O B-data
# B-function O B-tool, O O O O Ore O O B-data
# O O O B-app B-function O B-function O O appropriOe O
# O O O O O O O B-function I-function.
# O B-function O B-function O O O B-Ool B-data
# O O O O B-functiO Or B-app B-data O Or B-technique B-Ool
# O O O O O B-function O O B-app O B-data O O B-data I-data
# O B-system I-system, B-data O O O B-data I-data O O O O O B-data.
# O O O O O O O O O O O B-system  B-Ool B-feOture O O B-system O O B-system I-system.
# O B-tool O O O O O B-tool (B-dOtO) B-feOture B-functiO O B-system. SOce B-tool O O O O B-tool, O bOsic cOcepts O B-dOtO B-system, B-feOture, Ond B-feOture O O sOme.
# O B-system I-system, O O O B-data I-data, B-tool O B-tool O O B-data I-data.
# O B-tool B-data I-data O O O B-feature B-data.
# B-feature B-Ool B-feature I-feature O O O O B-data B-data, O O O O B-data usOg B-data.
# O O O O B-feature, B-system, O B-feature I-feature, O O O O B-feature
#
# B-dOa O O O B-feOure O O B-system B-system.
# O O B-system O O O O O B-dOtO I-dOtOO O O O O nOme O whOt O OctuOlly O
# O O O O O O B-data I-data O B-technique O O O B-app O B-data.
# O B-data B-feature O O O O B-data, O O O O O B-data O B-user O O O B-app O B-function
# O O O B-system O O B-data O O B-system I-system, O B-system O O O O O O B-data, B-data O B-data B-data.
# O B-system  O O B-system) wOnts O O B-dOtO viO B-Ool. O O O eOch B-system O B-function Os B-system B-Ool B-system.
# O O O B-dOtO O O B-dOtO O O O B-system I-system. O O B-system I-system I-system, B-system I-system O O B-function O O B-Ool O O B-system, O Oy O B-feOture O sOgle B-dOtO O O B-system I-system I-system
# O O O B-system I-system
# O O B-Ool, B-Ool O O O O O O O
# B-feature B-feature B-data I-data: O B-technique O B-feature B-feature I-feature
# O O B-technique: O O B-technique I-technique B-function O Oddress O O B-system O B-feOture
# O O B-system I-system I-system, O O O O O O
# B-technique O O B-dOtO O O O plOce insteOd O Occessing individuOl B-system
# B-feature O B-data O B-feature I-feature O O B-system.
# O O O O B-technique I-technique B-system O O plOce O O O B-technique I-technique cOpObility
# O O O O B-system I-system I-system
# O B-system I-system O O O O O B-system, O O O B-dOtO O O B-system I-system.
# O O B-system O O O O O B-data I-data, O O O O B-system I-system
# O B-system I-system O B-feature I-feature.
# O O B-system I-system O O On O O O O O O O B-dOa O O O B-system O O
# O O O B-system O O B-system O O O B-data B-feature O O B-system O O O O O O O O B-system I-system O O B-system I-system.
# O O O B-tool O B-system O B-data
# O O O B-data O O O B-system
# O O O O O O B-functiO Or B-system I-system O O O O O B-data O B-feature I-feature.
# O O O O O B-feature O B-feature I-feature.
# O O O B-feOture O O B-technique I-technique O O O O O
# O O O B-data O O B-feature O O O B-data O O O B-function I-function
# O O B-dOtO O O O B-dOtO I-dOtO
# O O O O O O O B-dOtO I-dOtO, O
# O wOh O O O thOn O B-dOtO I-dOtO O
# O O O O B-data I-data O O O O B-feature O
# B-system I-system O O O O O B-system, O O B-feature O O B-system I-system B-feature
# B-tool O O O O O O B-feature O B-data O O O O O B-system I-system.
# O O O B-data I-data O O O O B-feature, O O B-feature I-feature O O B-data, O On O B-tool B-system  (B-app, B-user, B-feature O
# O O O B-functiO O B-system I-system, O O O O O O O B-feature O O B-feature I-feature O B-feature
# O O B-data I-data, B-system B-data O O O O O
# B-feature O O O O O O B-system
# O O B-functiO B-tool O O B-system Ond O O B-system I-system
# O O O O O O O B-system
# B-functiO O B-system I-system, O O O O Ore O O B-data O O B-system
# O O O B-system I-system, B-data O O O O B-system O O B-feature B-system.
# O O O O O B-data I-data O O B-system.
# O O O O O O B-Opp I-Opp O O O Or B-system.
# O O O O O O O O O O O O O B-dOtO cOptured O Or B-system O O B-system I-system
# O O O O O B-function O O B-app O B-data O O B-data I-data
# O O O O O B-function O O B-tool B-data O B-data
# B-functiO O B-system I-system, O O O O Ore O O B-data O O B-system
# O O O O B-app B-function O O O B-function O O appropriOe O
# O O B-function B-Ool O B-function O B-Opp B-dOtO O O O B-dOtO I-dOtO?
# O O B-Opp B-dOtO O O B-function inO O B-system I-system?
# O O O B-app B-function O B-function O O appropriOe O
# O O O O O O O B-function I-function.
# B-feature B-feature O B-data.
# O O O B-function B-function O B-function O B-function Or B-Ool B-dOa O O O B-system I-system.

# %%
df2.to_csv('annotated_BIO.csv')

# %%
df = pd.read_csv(path + '/annotated_BIO.csv')

# %%
df.head()
# Out:
#   DocNo  Sno                                          sentence  \
# 0    D1    1                  Attacks can damage public domain
# 1    D1    2                     IDS means Intrusion Detection
# 2    D1    3             Snort is used for Intrusion Detection
# 3    D1    4                  Snort can detect network attacks
# 4    D1    5  Snort can also be used as a simple packet logger
#
#                                     tag
# 0        B-attack O O B-system I-system
# 1      B-tool O B-technique I-technique
# 2  B-tool O O O B-technique I-technique
# 3          B-tool O O B-attack I-attack
# 4    B-tool O O O O O O O B-tool I-tool

# %%
# add a blank row after each statement
df_new = pd.DataFrame()
for i, row in df.iterrows():
    df_new = df_new.append(row)
    for _ in range(1):
        df_new = df_new.append(pd.Series(), ignore_index=True)
# Out:
# <ipython-input-17-f767b3ba9cd9>:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_new = df_new.append(pd.Series(), ignore_index=True)

# %%
df_new.head(20)
# Out:
#    DocNo   Sno                                          sentence  \
# 0     D1   1.0                  Attacks can damage public domain
# 1    NaN   NaN                                               NaN
# 2     D1   2.0                     IDS means Intrusion Detection
# 3    NaN   NaN                                               NaN
# 4     D1   3.0             Snort is used for Intrusion Detection
# 5    NaN   NaN                                               NaN
# 6     D1   4.0                  Snort can detect network attacks
# 7    NaN   NaN                                               NaN
# 8     D1   5.0  Snort can also be used as a simple packet logger
# 9    NaN   NaN                                               NaN
# 10    D1   6.0               Snort can analyze real time traffic
# 11   NaN   NaN                                               NaN
# 12    D1   7.0             Snort can analyze real time data flow
# 13   NaN   NaN                                               NaN
# 14    D1   8.0                 Snort can check protocol analysis
# 15   NaN   NaN                                               NaN
# 16    D1   9.0       Snort can detect different types of attacks
# 17   NaN   NaN                                               NaN
# 18    D1  10.0        Snort checks the packet against user rules
# 19   NaN   NaN                                               NaN
#
#                                           tag
# 0              B-attack O O B-system I-system
# 1                                         NaN
# 2            B-tool O B-technique I-technique
# 3                                         NaN
# 4        B-tool O O O B-technique I-technique
# 5                                         NaN
# 6                B-tool O O B-attack I-attack
# 7                                         NaN
# 8          B-tool O O O O O O O B-tool I-tool
# 9                                         NaN
# 10                      B-tool O O O O B-data
# 11                                        NaN
# 12         B-tool O O O O B-feature I-feature
# 13                                        NaN
# 14         B-tool O O B-technique I-technique
# 15                                        NaN
# 16        B-tool O B-technique O O O B-attack
# 17                                        NaN
# 18  B-tool O O B-data O B-function I-function
# 19                                        NaN

# %%
df_new['Sno']=df_new['Sno'].fillna(0).astype('int')

# %%
df_new.head()
# Out:
#   DocNo  Sno                               sentence  \
# 0    D1    1       Attacks can damage public domain
# 1   NaN    0                                    NaN
# 2    D1    2          IDS means Intrusion Detection
# 3   NaN    0                                    NaN
# 4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag
# 0        B-attack O O B-system I-system
# 1                                   NaN
# 2      B-tool O B-technique I-technique
# 3                                   NaN
# 4  B-tool O O O B-technique I-technique

# %%
#df_new['DocNo']=df_new['DocNo'].fillna(0)

# %%
u = df_new.sentence.str.split(expand=True).stack()
v = df_new.tag.str.split(expand=True).stack()

# %%
len(u)
# Out:
# 8965

# %%
len(v)
# Out:
# 9010

# %%
u
# Out:
# 0     0      Attacks
#       1          can
#       2       damage
#       3       public
#       4       domain
#               ...
# 1182  12    received
#       13          at
#       14         the
#       15      server
#       16        side
# Length: 8965, dtype: object

# %%
v
# Out:
# 0     0     B-attack
#       1            O
#       2            O
#       3     B-system
#       4     I-system
#               ...
# 1182  12           O
#       13           O
#       14           O
#       15    B-system
#       16    I-system
# Length: 9010, dtype: object

# %%
df_new.head(-10)
# Out:
#      DocNo  Sno                                           sentence  \
# 0       D1    1                   Attacks can damage public domain
# 1      NaN    0                                                NaN
# 2       D1    2                      IDS means Intrusion Detection
# 3      NaN    0                                                NaN
# 4       D1    3              Snort is used for Intrusion Detection
# ...    ...  ...                                                ...
# 1169   NaN    0                                                NaN
# 1170    D6  586  How to modify the iptables rules to let it log...
# 1171   NaN    0                                                NaN
# 1172    D6  587  How to configure syslog to log the iptables me...
# 1173   NaN    0                                                NaN
#
#                                                     tag
# 0                        B-attack O O B-system I-system
# 1                                                   NaN
# 2                      B-tool O B-technique I-technique
# 3                                                   NaN
# 4                  B-tool O O O B-technique I-technique
# ...                                                 ...
# 1169                                                NaN
# 1170  O O O O B-app B-function O O O B-function O O O O
# 1171                                                NaN
# 1172  O O B-function B-tool O B-function O B-app B-d...
# 1173                                                NaN
#
# [1174 rows x 4 columns]

# %%
v[-10:]
# Out:
# 1182  7              O
#       8     B-function
#       9              O
#       10        B-tool
#       11        B-data
#       12             O
#       13             O
#       14             O
#       15      B-system
#       16      I-system
# dtype: object

# %%
df_new['c1'] = df_new['sentence'].str.split().str.len()

# %%
df_new['c2'] = df_new['tag'].str.split().str.len()

# %%
df_new['c1']=df_new['c1'].fillna(0).astype('int')
df_new['c2']=df_new['c2'].fillna(0).astype('int')

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 DocNo  Sno                               sentence  \
# 0           0             0    D1    1       Attacks can damage public domain
# 1           1             1   NaN    0                                    NaN
# 2           2             2    D1    2          IDS means Intrusion Detection
# 3           3             3   NaN    0                                    NaN
# 4           4             4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                   NaN   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                   NaN   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
df_new['compare']= np.where((df_new['c1'] != df_new['c2']), 0,1)

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 DocNo  Sno                               sentence  \
# 0           0             0    D1    1       Attacks can damage public domain
# 1           1             1   NaN    0                                    NaN
# 2           2             2    D1    2          IDS means Intrusion Detection
# 3           3             3   NaN    0                                    NaN
# 4           4             4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                   NaN   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                   NaN   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
df_new.to_csv('temp.csv')

# %%
df_new = pd.read_csv(path + '/temp.csv')

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 DocNo  Sno  \
# 0           0             0               0    D1    1
# 1           1             1               1   NaN    0
# 2           2             2               2    D1    2
# 3           3             3               3   NaN    0
# 4           4             4               4    D1    3
#
#                                 sentence  \
# 0       Attacks can damage public domain
# 1                                  blank
# 2          IDS means Intrusion Detection
# 3                                  blank
# 4  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                 blank   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                 blank   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
ds.head()
# Out:
#   sentence       tag
# 0  Attacks  B-attack
# 1      can         O
# 2   damage         O
# 3   public  B-system
# 4   domain  I-system

# %%
# insert blanks
df_new['sentence']=df_new['sentence'].fillna('blank')

# %%
df_new['tag']=df_new['tag'].fillna('blank')

# %%
# split the sentence into words
u = df_new.sentence.str.split(expand=True).stack()
v = df_new.tag.str.split(expand=True).stack()


dsp = pd.DataFrame({
    'sentence': u.values, 
    'tag': v.values, 
})

# %%
dsp.head(15)
# Out:
#      sentence          tag
# 0     Attacks     B-attack
# 1         can            O
# 2      damage            O
# 3      public     B-system
# 4      domain     I-system
# 5       blank        blank
# 6         IDS       B-tool
# 7       means            O
# 8   Intrusion  B-technique
# 9   Detection  I-technique
# 10      blank        blank
# 11      Snort       B-tool
# 12         is            O
# 13       used            O
# 14        for            O

# %%
dsp.to_csv('splitdata.csv')

# %%
dsp = pd.read_csv(path + '/splitdata.csv')

# %%
dsp.head()
# Out:
#   DocNo  Unnamed: 1 sentence       tag
# 0    D1           0  Attacks  B-attack
# 1    D1           1      can         O
# 2    D1           2   damage         O
# 3    D1           3   public  B-system
# 4    D1           4   domain  I-system

# %%
dsp = dsp.drop('Unnamed: 1', axis=1)

# %%
dsp.head(10)
# Out:
#   DocNo   sentence          tag
# 0    D1    Attacks     B-attack
# 1    D1        can            O
# 2    D1     damage            O
# 3    D1     public     B-system
# 4    D1     domain     I-system
# 5    D1      blank        blank
# 6    D1        IDS       B-tool
# 7    D1      means            O
# 8    D1  Intrusion  B-technique
# 9    D1  Detection  I-technique

# %%
dsp['DocNo'].mask(dsp['sentence'] == 'blank', 'blank', inplace=True)

# %%
dsp.head(20)
# Out:
#     DocNo   sentence          tag
# 0      D1    Attacks     B-attack
# 1      D1        can            O
# 2      D1     damage            O
# 3      D1     public     B-system
# 4      D1     domain     I-system
# 5   blank      blank        blank
# 6      D1        IDS       B-tool
# 7      D1      means            O
# 8      D1  Intrusion  B-technique
# 9      D1  Detection  I-technique
# 10  blank      blank        blank
# 11     D1      Snort       B-tool
# 12     D1         is            O
# 13     D1       used            O
# 14     D1        for            O
# 15     D1  Intrusion  B-technique
# 16     D1  Detection  I-technique
# 17  blank      blank        blank
# 18     D1      Snort       B-tool
# 19     D1        can            O

# %%
dsp.to_csv('splitdata.csv')
