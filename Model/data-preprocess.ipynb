# %%
import pandas as pd
import csv
import os
import numpy as np
import nltk
import re

# %%
from nltk.tokenize import word_tokenize

# %%
path=os.getcwd()
path
# Out:
# '/Users/garima/AISecKG-cybersecurity-dataset/Model'

# %%
annotatedata = pd.read_csv(path + '/annotated_data_BI.csv')

# %%
annotatedata.head()
# Out:
#                                             sentence  \
# 0                  Attacks can damage public domain.
# 1                      IDS means Intrusion Detection
# 2              Snort is used for Intrusion Detection
# 3                  Snort can detect network attacks.
# 4  Snort can also be used as a simple packet logger.
#
#                                               entity
# 0             B-attack can damage B-system I-system.
# 1               B-tool means B-technique I-technique
# 2         B-tool is used for B-technique I-technique
# 3               B-tool can detect B-attack I-attack.
# 4  B-tool can also be used as a simple B-tool I-t...

# %%
punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

# %%
for ele in annotatedata['sentence']:
    if ele in punc:
        annotatedata['sentence'] = annotatedata['sentence'].replace(ele, "")

# %%
regex1 = re.compile('B-')
regex2 = re.compile('I-')

# %%
annotatedata.head()
# Out:
#                                             sentence  \
# 0                  Attacks can damage public domain.
# 1                      IDS means Intrusion Detection
# 2              Snort is used for Intrusion Detection
# 3                  Snort can detect network attacks.
# 4  Snort can also be used as a simple packet logger.
#
#                                               entity
# 0             B-attack can damage B-system I-system.
# 1               B-tool means B-technique I-technique
# 2         B-tool is used for B-technique I-technique
# 3               B-tool can detect B-attack I-attack.
# 4  B-tool can also be used as a simple B-tool I-t...

# %%
df2=pd.DataFrame(columns=['tag'])

# %%
for row in annotatedata['entity']:
    for word in row.split():
        res1 = regex1.search(word)
        res2= regex2.search(word)
        if res1==None and res2==None:
            row=row.replace(word,'O')
    #print(row)
    df2 = df2.append(pd.DataFrame([row], columns=['tag']))

# %%
df2.to_csv('annotated_BIO.csv')

# %%
df = pd.read_csv(path + '/annotated_BIO.csv')

# %%
df.head()
# Out:
#   DocNo  Sno                                          sentence  \
# 0    D1    1                  Attacks can damage public domain
# 1    D1    2                     IDS means Intrusion Detection
# 2    D1    3             Snort is used for Intrusion Detection
# 3    D1    4                  Snort can detect network attacks
# 4    D1    5  Snort can also be used as a simple packet logger
#
#                                     tag
# 0        B-attack O O B-system I-system
# 1      B-tool O B-technique I-technique
# 2  B-tool O O O B-technique I-technique
# 3          B-tool O O B-attack I-attack
# 4    B-tool O O O O O O O B-tool I-tool

# %%
# add a blank row after each statement
df_new = pd.DataFrame()
for i, row in df.iterrows():
    df_new = df_new.append(row)
    for _ in range(1):
        df_new = df_new.append(pd.Series(), ignore_index=True)
# Out:
# <ipython-input-17-f767b3ba9cd9>:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_new = df_new.append(pd.Series(), ignore_index=True)

# %%
df_new.head(20)
# Out:
#    DocNo   Sno                                          sentence  \
# 0     D1   1.0                  Attacks can damage public domain
# 1    NaN   NaN                                               NaN
# 2     D1   2.0                     IDS means Intrusion Detection
# 3    NaN   NaN                                               NaN
# 4     D1   3.0             Snort is used for Intrusion Detection
# 5    NaN   NaN                                               NaN
# 6     D1   4.0                  Snort can detect network attacks
# 7    NaN   NaN                                               NaN
# 8     D1   5.0  Snort can also be used as a simple packet logger
# 9    NaN   NaN                                               NaN
# 10    D1   6.0               Snort can analyze real time traffic
# 11   NaN   NaN                                               NaN
# 12    D1   7.0             Snort can analyze real time data flow
# 13   NaN   NaN                                               NaN
# 14    D1   8.0                 Snort can check protocol analysis
# 15   NaN   NaN                                               NaN
# 16    D1   9.0       Snort can detect different types of attacks
# 17   NaN   NaN                                               NaN
# 18    D1  10.0        Snort checks the packet against user rules
# 19   NaN   NaN                                               NaN
#
#                                           tag
# 0              B-attack O O B-system I-system
# 1                                         NaN
# 2            B-tool O B-technique I-technique
# 3                                         NaN
# 4        B-tool O O O B-technique I-technique
# 5                                         NaN
# 6                B-tool O O B-attack I-attack
# 7                                         NaN
# 8          B-tool O O O O O O O B-tool I-tool
# 9                                         NaN
# 10                      B-tool O O O O B-data
# 11                                        NaN
# 12         B-tool O O O O B-feature I-feature
# 13                                        NaN
# 14         B-tool O O B-technique I-technique
# 15                                        NaN
# 16        B-tool O B-technique O O O B-attack
# 17                                        NaN
# 18  B-tool O O B-data O B-function I-function
# 19                                        NaN

# %%
df_new['Sno']=df_new['Sno'].fillna(0).astype('int')

# %%
df_new.head()
# Out:
#   DocNo  Sno                               sentence  \
# 0    D1    1       Attacks can damage public domain
# 1   NaN    0                                    NaN
# 2    D1    2          IDS means Intrusion Detection
# 3   NaN    0                                    NaN
# 4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag
# 0        B-attack O O B-system I-system
# 1                                   NaN
# 2      B-tool O B-technique I-technique
# 3                                   NaN
# 4  B-tool O O O B-technique I-technique

# %%
#df_new['DocNo']=df_new['DocNo'].fillna(0)

# %%
u = df_new.sentence.str.split(expand=True).stack()
v = df_new.tag.str.split(expand=True).stack()

# %%
len(u)
# Out:
# 8965

# %%
len(v)
# Out:
# 9010

# %%
u
# Out:
# 0     0      Attacks
#       1          can
#       2       damage
#       3       public
#       4       domain
#               ...
# 1182  12    received
#       13          at
#       14         the
#       15      server
#       16        side
# Length: 8965, dtype: object

# %%
v
# Out:
# 0     0     B-attack
#       1            O
#       2            O
#       3     B-system
#       4     I-system
#               ...
# 1182  12           O
#       13           O
#       14           O
#       15    B-system
#       16    I-system
# Length: 9010, dtype: object

# %%
df_new.head(-10)
# Out:
#      DocNo  Sno                                           sentence  \
# 0       D1    1                   Attacks can damage public domain
# 1      NaN    0                                                NaN
# 2       D1    2                      IDS means Intrusion Detection
# 3      NaN    0                                                NaN
# 4       D1    3              Snort is used for Intrusion Detection
# ...    ...  ...                                                ...
# 1169   NaN    0                                                NaN
# 1170    D6  586  How to modify the iptables rules to let it log...
# 1171   NaN    0                                                NaN
# 1172    D6  587  How to configure syslog to log the iptables me...
# 1173   NaN    0                                                NaN
#
#                                                     tag
# 0                        B-attack O O B-system I-system
# 1                                                   NaN
# 2                      B-tool O B-technique I-technique
# 3                                                   NaN
# 4                  B-tool O O O B-technique I-technique
# ...                                                 ...
# 1169                                                NaN
# 1170  O O O O B-app B-function O O O B-function O O O O
# 1171                                                NaN
# 1172  O O B-function B-tool O B-function O B-app B-d...
# 1173                                                NaN
#
# [1174 rows x 4 columns]

# %%
v[-10:]
# Out:
# 1182  7              O
#       8     B-function
#       9              O
#       10        B-tool
#       11        B-data
#       12             O
#       13             O
#       14             O
#       15      B-system
#       16      I-system
# dtype: object

# %%
df_new['c1'] = df_new['sentence'].str.split().str.len()

# %%
df_new['c2'] = df_new['tag'].str.split().str.len()

# %%
df_new['c1']=df_new['c1'].fillna(0).astype('int')
df_new['c2']=df_new['c2'].fillna(0).astype('int')

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 DocNo  Sno                               sentence  \
# 0           0             0    D1    1       Attacks can damage public domain
# 1           1             1   NaN    0                                    NaN
# 2           2             2    D1    2          IDS means Intrusion Detection
# 3           3             3   NaN    0                                    NaN
# 4           4             4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                   NaN   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                   NaN   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
df_new['compare']= np.where((df_new['c1'] != df_new['c2']), 0,1)

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 DocNo  Sno                               sentence  \
# 0           0             0    D1    1       Attacks can damage public domain
# 1           1             1   NaN    0                                    NaN
# 2           2             2    D1    2          IDS means Intrusion Detection
# 3           3             3   NaN    0                                    NaN
# 4           4             4    D1    3  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                   NaN   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                   NaN   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
df_new.to_csv('temp.csv')

# %%
df_new = pd.read_csv(path + '/temp.csv')

# %%
df_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 DocNo  Sno  \
# 0           0             0               0    D1    1
# 1           1             1               1   NaN    0
# 2           2             2               2    D1    2
# 3           3             3               3   NaN    0
# 4           4             4               4    D1    3
#
#                                 sentence  \
# 0       Attacks can damage public domain
# 1                                  blank
# 2          IDS means Intrusion Detection
# 3                                  blank
# 4  Snort is used for Intrusion Detection
#
#                                     tag  c1  c2  compare
# 0        B-attack O O B-system I-system   5   5        1
# 1                                 blank   0   0        1
# 2      B-tool O B-technique I-technique   4   4        1
# 3                                 blank   0   0        1
# 4  B-tool O O O B-technique I-technique   6   6        1

# %%
ds.head()
# Out:
#   sentence       tag
# 0  Attacks  B-attack
# 1      can         O
# 2   damage         O
# 3   public  B-system
# 4   domain  I-system

# %%
# insert blanks
df_new['sentence']=df_new['sentence'].fillna('blank')

# %%
df_new['tag']=df_new['tag'].fillna('blank')

# %%
# split the sentence into words
u = df_new.sentence.str.split(expand=True).stack()
v = df_new.tag.str.split(expand=True).stack()


dsp = pd.DataFrame({
    'sentence': u.values, 
    'tag': v.values, 
})

# %%
dsp.head(15)
# Out:
#      sentence          tag
# 0     Attacks     B-attack
# 1         can            O
# 2      damage            O
# 3      public     B-system
# 4      domain     I-system
# 5       blank        blank
# 6         IDS       B-tool
# 7       means            O
# 8   Intrusion  B-technique
# 9   Detection  I-technique
# 10      blank        blank
# 11      Snort       B-tool
# 12         is            O
# 13       used            O
# 14        for            O

# %%
dsp.to_csv('splitdata.csv')

# %%
dsp = pd.read_csv(path + '/splitdata.csv')

# %%
dsp.head()
# Out:
#   DocNo  Unnamed: 1 sentence       tag
# 0    D1           0  Attacks  B-attack
# 1    D1           1      can         O
# 2    D1           2   damage         O
# 3    D1           3   public  B-system
# 4    D1           4   domain  I-system

# %%
dsp = dsp.drop('Unnamed: 1', axis=1)

# %%
dsp.head(10)
# Out:
#   DocNo   sentence          tag
# 0    D1    Attacks     B-attack
# 1    D1        can            O
# 2    D1     damage            O
# 3    D1     public     B-system
# 4    D1     domain     I-system
# 5    D1      blank        blank
# 6    D1        IDS       B-tool
# 7    D1      means            O
# 8    D1  Intrusion  B-technique
# 9    D1  Detection  I-technique

# %%
dsp['DocNo'].mask(dsp['sentence'] == 'blank', 'blank', inplace=True)

# %%
dsp.head(20)
# Out:
#     DocNo   sentence          tag
# 0      D1    Attacks     B-attack
# 1      D1        can            O
# 2      D1     damage            O
# 3      D1     public     B-system
# 4      D1     domain     I-system
# 5   blank      blank        blank
# 6      D1        IDS       B-tool
# 7      D1      means            O
# 8      D1  Intrusion  B-technique
# 9      D1  Detection  I-technique
# 10  blank      blank        blank
# 11     D1      Snort       B-tool
# 12     D1         is            O
# 13     D1       used            O
# 14     D1        for            O
# 15     D1  Intrusion  B-technique
# 16     D1  Detection  I-technique
# 17  blank      blank        blank
# 18     D1      Snort       B-tool
# 19     D1        can            O

# %%
dsp.to_csv('splitdata.csv')

# %%
dsf = pd.read_csv(path + '/splitdata_final.csv')

# %%
dsf = dsf.fillna("")
dsf.tag.unique()
# Out:
# array(['B-attack', 'O', 'B-system', 'I-system', '', 'B-tool',
#        'B-technique', 'I-technique', 'I-attack', 'I-tool', 'B-data',
#        'B-feature', 'I-feature', 'B-function', 'I-function', 'I-data',
#        'B-vulnerability', 'I-vulnerability', 'B-app', 'B-securityTeam',
#        'I-securityTeam', 'B-attacker', 'I-attacker', 'B-user', 'I-app',
#        'I-user'], dtype=object)

# %%
dsf= dsf.drop('DocNo', axis=1)

# %%
dsf.head()
# Out:
#   sentence       tag
# 0  Attacks  B-attack
# 1      can         O
# 2   damage         O
# 3   public  B-system
# 4   domain  I-system

# %%
# remove the other words
df_entity = dsf[dsf['tag'] != 'O']

# %%
len(df_entity)
# Out:
# 3833

# %%
# schema as per ontology
schema = [
('user', 'uses', 'app'), 
('user', 'uses', 'system'), 
('user', 'uses', 'data'), 
('app', 'uses', 'data'), 
('system', 'uses', 'data'), 
('system', 'has_a', 'tool'), 
('app', 'has_a', 'tool'),
('tool', 'is_part_of', 'system'),
('tool', 'is_part_of', 'app'),
('tool', 'is_a', 'tool'),
('tool', 'has_a', 'function'),
('tool', 'has_a', 'feature'),
('function', 'has_a', 'feature'),
('feature', 'is_part_of', 'tool'),
('system', 'has_a', 'feature'),
('app', 'has_a', 'feature'),
('feature', 'uses', 'data'),
('tool', 'uses', 'data'), 
('app', 'can_expose', 'vulnerability'),
('system', 'can_expose', 'vulnerability'),
('data', 'can_expose', 'vulnerability'),
('feature', 'can_expose', 'vulnerability'),
('attacker', 'can_exploit', 'vulnerability'),
('attacker', 'uses', 'feature'),
('attacker', 'uses', 'function'),
('attacker', 'uses', 'tool'),
('attacker', 'implements', 'attack'),
('attacker', 'uses', 'technique'),
('technique', 'implements', 'attack'),
('attacker', 'can_harm', 'app'),
('attacker', 'can_harm', 'data'),
('attacker', 'can_harm', 'system'),
('attack', 'is_a', 'attack'), 
('attack', 'can_harm', 'system'),
('attack', 'can_harm', 'app'),
('attack', 'can_harm', 'data'), 
('securityTeam', 'can_analyze', 'app'),
('securityTeam', 'can_analyze', 'data'),
('securityTeam', 'can_analyze', 'system'),
('securityTeam', 'uses', 'tool'),
('securityTeam', 'implements', 'function'),
('securityTeam', 'can_analyze', 'feature'),
('securityTeam', 'uses', 'technique'),
('securityTeam', 'can_detect', 'vulnerability'),
('securityTeam', 'can_analyze', 'attack'),
('tool', 'can_analyze', 'system'),
('tool', 'can_analyze', 'app'),
('tool', 'can_analyze', 'data'),
('tool', 'can_analyze', 'vulnerability'),
('tool', 'can_detect', 'attack'),
('function', 'can_analyze', 'vulnerability'),
('function', 'can_analyze', 'system'),
('function', 'can_analyze', 'app'),
('function', 'can_analyze', 'data'),
('function', 'can_detect', 'attack'),
('feature', 'can_analyze', 'system'),
('feature', 'can_analyze', 'app'),
('feature', 'can_analyze', 'data'),
('feature', 'can_analyze', 'vulnerability') ,
('feature', 'can_detect', 'attack') ,
('technique', 'can_analyze', 'vulnerability'), 
('technique', 'can_detect', 'attack')
]

# %%
df_entity.to_csv('temp2.csv')

# %%
df_entity.head(10)
# Out:
#       sentence          tag
# 0     Attacks,     B-attack
# 3      public,     B-system
# 4      domain,     I-system
# 5            ,
# 6         IDS,       B-tool
# 8   Intrusion,  B-technique
# 9   Detection,  I-technique
# 10           ,
# 11      Snort,       B-tool
# 15  Intrusion,  B-technique

# %%
df_entity.sentence
# Out:
# 0        Attacks
# 3         public
# 4         domain
# 5
# 6            IDS
#           ...
# 9549        test
# 9551    firewall
# 9552        logs
# 9556      server
# 9557        side
# Name: sentence, Length: 3833, dtype: object

# %%
df_entity['sentence']= df_entity['sentence'].apply(lambda x:"{:},".format(x))
# Out:
# <ipython-input-61-262552ce83cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_entity['sentence']= df_entity['sentence'].apply(lambda x:"{:},".format(x))

# %%
dfc= df_entity.groupby((~df_entity.tag.str.startswith('I')).cumsum(), as_index=False).sum()

# %%
dfc.head(10)
# Out:
#                sentence                     tag
# 0              Attacks,                B-attack
# 1        public,domain,        B-systemI-system
# 2                     ,
# 3                  IDS,                  B-tool
# 4  Intrusion,Detection,  B-techniqueI-technique
# 5                     ,
# 6                Snort,                  B-tool
# 7  Intrusion,Detection,  B-techniqueI-technique
# 8                     ,
# 9                Snort,                  B-tool

# %%
dfc.to_csv('temp2.csv')

# %%
dfc = pd.read_csv(path + '/temp2.csv')

# %%
dfc.head(10)
# Out:
#    Unnamed: 0              sentence                     tag
# 0           0              Attacks                 B-attack
# 1           1        public domain         B-systemI-system
# 2           2                                           NaN
# 3           3                  IDS                   B-tool
# 4           4  Intrusion Detection   B-techniqueI-technique
# 5           5                                           NaN
# 6           6                Snort                   B-tool
# 7           7  Intrusion Detection   B-techniqueI-technique
# 8           8                                           NaN
# 9           9                Snort                   B-tool

# %%
#dfc.dropna(subset=['tag'], inplace=True)

# %%
dfc['tag'] = dfc['tag'].str.replace('','')
# Out:
# <ipython-input-78-4e634ccb6785>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfc['tag'] = dfc['tag'].str.replace('I-?','')

# %%
dfc['tag'] = dfc['tag'].str.replace('I-attack',' ')

# %%
dfc['tag'] = dfc['tag'].str.replace('I-tool',' ')

# %%
dfc['tag'] = dfc['tag'].str.replace('I-system',' ')

# %%
dfc['tag'] = dfc['tag'].str.replace('I-feature',' ')
dfc['tag'] = dfc['tag'].str.replace('I-function',' ')
dfc['tag'] = dfc['tag'].str.replace('I-technique',' ')
dfc['tag'] = dfc['tag'].str.replace('I-data',' ')
dfc['tag'] = dfc['tag'].str.replace('I-user',' ')
dfc['tag'] = dfc['tag'].str.replace('I-vulnerability',' ')
dfc['tag'] = dfc['tag'].str.replace('I-app',' ')
dfc['tag'] = dfc['tag'].str.replace('I-securityTeam',' ')
dfc['tag'] = dfc['tag'].str.replace('I-attacker',' ')

# %%
import re

# %%
dfc['tag'] = dfc['tag'].str.replace('B-',' ')

# %%
dfc.to_csv('temp2.csv')

# %%
dfc['entity']=list(zip(dfc.sentence, dfc.tag))

# %%
dfc.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1              sentence          tag  \
# 0           0             0              Attacks        attack
# 1           1             1        public domain       system
# 2           2             2                                NaN
# 3           3             3                  IDS          tool
# 4           4             4  Intrusion Detection    technique
#
#                                     entity
# 0                  ('Attacks ', ' attack')
# 1           ('public domain ', ' system ')
# 2
# 3                        ('IDS ', ' tool')
# 4  ('Intrusion Detection ', ' technique ')

# %%
# create tuples
entity_list = dfc['entity'].tolist()

# %%
entity_list
# Out:
# ["('Attacks ', ' attack')",
#  "('public domain ', ' system ')",
#  ' ',
#  "('IDS ', ' tool')",
#  "('Intrusion Detection ', ' technique ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Intrusion Detection ', ' technique ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('network attacks ', ' attack ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('packet logger ', ' tool ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('traffic ', ' data')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('data flow ', ' feature ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('protocol analysis ', ' technique ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('detect ', ' technique')",
#  "('attacks ', ' attack')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('packet ', ' data')",
#  "('user rules ', ' function ')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  "('language ', ' feature')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('previous ', ' feature')",
#  "('attack ', ' feature')",
#  "('pattern ', ' feature')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('network ', ' feature')",
#  "('behavior ', ' feature')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('bad packet ', ' data ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Packet Decoder ', ' tool ')",
#  ' ',
#  "('Packet Decoder ', ' tool ')",
#  "('packets ', ' data')",
#  ' ',
#  "('Packet Decoder ', ' tool ')",
#  "('protocols ', ' feature')",
#  ' ',
#  "('Packet Decoder ', ' tool ')",
#  "('packet ', ' data')",
#  "('data size ', ' feature ')",
#  ' ',
#  "('Packet Decoder ', ' tool ')",
#  "('header anomalies ', ' vulnerability ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Preprocessor ', ' tool')",
#  ' ',
#  "('Preprocessor ', ' tool')",
#  "('HTTP anomalies ', ' vulnerability ')",
#  ' ',
#  "('Preprocessor ', ' tool')",
#  "('FTP anomalies ', ' vulnerability ')",
#  ' ',
#  "('Preprocessor ', ' tool')",
#  "('packet data ', ' data ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Detection Engine ', ' tool ')",
#  ' ',
#  "('Detection Engine ', ' tool ')",
#  "('detects ', ' technique')",
#  "('intrusion ', ' attack')",
#  "('packet ', ' data')",
#  ' ',
#  "('Detection Engine ', ' tool ')",
#  "('rules ', ' function')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Log Alert system ', ' tool  ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Output Module ', ' tool ')",
#  ' ',
#  "('Output Module ', ' tool ')",
#  "('output ', ' feature')",
#  "('type ', ' feature')",
#  ' ',
#  "('Output Module ', ' tool ')",
#  "('alerts ', ' feature')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('Sniff mode ', ' feature ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('sniff ', ' technique')",
#  "('Ingress ', ' feature')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('sniff ', ' technique')",
#  "('Egress ', ' feature')",
#  ' ',
#  "('Ingress ', ' feature')",
#  "('incoming traffic ', ' data ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('sniffs ', ' technique')",
#  "('firewall traffic ', ' data ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('packet logger ', ' tool ')",
#  ' ',
#  "('packet logger ', ' tool ')",
#  "('data ', ' data')",
#  "('file ', ' data')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('tcpdump pcap ', ' data ')",
#  ' ',
#  "('Snort ', ' tool')",
#  "('unified2 ', ' tool')",
#  ' ',
#  "('Wireshark ', ' tool')",
#  "('tcpdump pcap ', ' data ')",
#  ' ',
#  "('Detection alert ', ' tool ')",
#  "('IP packets ', ' data ')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  "('icmp rules ', ' function ')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  "('system variables ', ' data ')",
#  ' ',
#  "('system variables ', ' data ')",
#  "('conf file ', ' data ')",
#  ' ',
#  "('system variables ', ' data ')",
#  "('home network ', ' system ')",
#  ' ',
#  "('system variables ', ' data ')",
#  "('external network ', ' system ')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  "('payload options ', ' feature ')",
#  ' ',
#  "('payload options ', ' feature ')",
#  "('data ', ' data')",
#  ' ',
#  "('Snort rules ', ' function ')",
#  "('non payload options ', ' feature  ')",
#  ' ',
#  "('Network ', ' system')",
#  "('client gateway server ', ' system  ')",
#  ' ',
#  "('Packet forwarding ', ' feature ')",
#  "('Gateway ', ' system')",
#  ' ',
#  "('Firewall ', ' tool')",
#  "('sniff ', ' technique')",
#  "('server ', ' system')",
#  ' ',
#  "('Firewall ', ' tool')",
#  "('testing ', ' function')",
#  ' ',
#  "('Blacklist ', ' feature')",
#  "('testing ', ' function')",
#  ' ',
#  "('Land Attack ', ' attack ')",
#  "('spoofed ', ' vulnerability')",
#  "('TCP SYN Packets ', ' data  ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('open source ', ' feature ')",
#  "('tool ', ' tool')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('network discovery ', ' technique ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('security auditing ', ' technique ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('exposed ', ' vulnerability')",
#  "('services ', ' app')",
#  "('target machine ', ' system ')",
#  "('information ', ' data')",
#  "('version ', ' technique')",
#  "('OS detection ', ' technique ')",
#  ' ',
#  "('nmap ', ' tool')",
#  "('packets ', ' data')",
#  "('network diagnostic ', ' technique ')",
#  "('testing ', ' function')",
#  ' ',
#  "('nmap ', ' tool')",
#  "('packets ', ' data')",
#  "('attacks ', ' attack')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('network mapper ', ' feature ')",
#  "('network discovery ', ' technique ')",
#  "('tools ', ' tool')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('tools ', ' tool')",
#  "('network administrators ', ' securityTeam ')",
#  "('map ', ' function')",
#  "('networks ', ' system')",
#  ' ',
#  "('program ', ' function')",
#  "('live hosts ', ' system ')",
#  "('network ', ' system')",
#  "('port scanning ', ' technique ')",
#  "('ping sweeps ', ' technique ')",
#  "('OS detection ', ' technique ')",
#  "('version detection ', ' technique ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('network scanning ', ' technique ')",
#  "('tool ', ' tool')",
#  "('IP packets ', ' data ')",
#  "('devices ', ' system')",
#  "('network ', ' system')",
#  "('information ', ' data')",
#  "('services ', ' app')",
#  "('operating systems ', ' system ')",
#  ' ',
#  "('command-line interface ', ' tool ')",
#  "('GUI front-ends ', ' tool ')",
#  ' ',
#  "('operating systems ', ' system ')",
#  "('Linux ', ' system')",
#  "('Free BSD ', ' system ')",
#  "('Gentoo ', ' system')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('enterprise-scale networks ', ' system ')",
#  "('scan ', ' function')",
#  "('connected devices ', ' system ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('IoT security ', ' technique ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('information ', ' data')",
#  "('active ', ' feature')",
#  "('IP ', ' feature')",
#  "('IP ', ' feature')",
#  "('legitimate ', ' feature')",
#  "('service ', ' app')",
#  "('external attacker ', ' attacker er')",
#  ' ',
#  "('network ', ' system')",
#  "('live hosts ', ' system ')",
#  "('open ports ', ' feature ')",
#  "('OS ', ' system')",
#  "('connected device ', ' system ')",
#  ' ',
#  "('Vulnerabilities ', ' vulnerability')",
#  "('scan ', ' function')",
#  "('server ', ' system')",
#  "('process ', ' technique')",
#  "('hacker ', ' attacker')",
#  "('attack ', ' attack')",
#  "('site ', ' system')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('processes ', ' technique')",
#  ' ',
#  "('information ', ' data')",
#  "('IP ', ' feature')",
#  "('active ', ' feature')",
#  "('networks ', ' system')",
#  "('IP ', ' feature')",
#  "('scanned ', ' function')",
#  ' ',
#  "('administrators ', ' securityTeam')",
#  "('IP ', ' feature')",
#  "('legitimate service ', ' feature ')",
#  "('external attacker ', ' attacker er')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('information ', ' data')",
#  "('network ', ' system')",
#  ' ',
#  "('live hosts ', ' system ')",
#  "('open ports ', ' feature ')",
#  "('OS ', ' system')",
#  "('connected device ', ' system ')",
#  ' ',
#  "('tool ', ' tool')",
#  "('system monitoring ', ' technique ')",
#  "('pentesting ', ' technique')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('Metasploit framework ', ' tool ')",
#  "('probe ', ' technique')",
#  "('network vulnerabilities ', ' vulnerability ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('tool ', ' tool')",
#  "('users ', ' user')",
#  "('personal ', ' system')",
#  "('business websites ', ' system ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('scan ', ' technique')",
#  "('web server ', ' system ')",
#  "('hosting ', ' feature')",
#  "('website ', ' system')",
#  "('home ', ' system')",
#  "('hacker ', ' attacker')",
#  "('process ', ' technique')",
#  "('attack ', ' attack')",
#  "('site ', ' system')",
#  ' ',
#  "('Attacking ', ' attack')",
#  "('site ', ' system')",
#  "('security vulnerabilities ', ' vulnerability ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('tools ', ' tool')",
#  "('system admins ', ' securityTeam ')",
#  "('programs ', ' function')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('tools ', ' tool')",
#  "('program ', ' function')",
#  "('network monitoring ', ' technique ')",
#  "('tools ', ' tool')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('command-line interfaces ', ' tool ')",
#  ' ',
#  "('users ', ' user')",
#  "('scripts ', ' function')",
#  "('automate ', ' feature')",
#  "('network monitoring ', ' technique ')",
#  ' ',
#  "('TCP Full Connect Vanilla Scan ', ' technique    ')",
#  ' ',
#  "('scanning ', ' technique')",
#  "('target�s ', ' system')",
#  "('IP address ', ' feature ')",
#  ' ',
#  "('TCP Connect scan ', ' technique  ')",
#  "('3-way handshake ', ' technique ')",
#  ' ',
#  "('port ', ' feature')",
#  "('open ', ' feature')",
#  "('operating system ', ' system ')",
#  "('TCP ', ' feature')",
#  "('three-way handshake ', ' technique ')",
#  "('port scanner ', ' tool ')",
#  "('connection ', ' feature')",
#  "('DOS ', ' attack')",
#  ' ',
#  "('noisy ', ' feature')",
#  "('services ', ' feature')",
#  "('log ', ' function')",
#  "('sender ', ' system')",
#  "('IP address ', ' feature ')",
#  "('Intrusion Detection Systems ', ' tool  ')",
#  ' ',
#  "('Full scan ', ' technique ')",
#  ' ',
#  "('3-way handshake ', ' technique ')",
#  "('scanned ', ' vulnerability')",
#  "('port ', ' feature')",
#  ' ',
#  "('Sends ', ' function')",
#  "('SYN ', ' feature')",
#  "('ACK ', ' feature')",
#  "('sending ', ' function')",
#  "('ACK ', ' feature')",
#  ' ',
#  "('Tears down ', ' feature ')",
#  "('connection ', ' feature')",
#  "('FIN packets ', ' data ')",
#  ' ',
#  "('target port ', ' feature ')",
#  "('closed ', ' feature')",
#  "('sender ', ' system')",
#  "('received ', ' function')",
#  "('response ', ' feature')",
#  "('RESET packet ', ' data ')",
#  "('ICMP Port Unreachable packet ', ' data   ')",
#  ' ',
#  "('stealthy ', ' vulnerability')",
#  "('connection request ', ' feature ')",
#  "('logged ', ' function')",
#  ' ',
#  "('UDP scan ', ' technique ')",
#  "('UDP ports ', ' feature ')",
#  "('listening ', ' feature')",
#  ' ',
#  "('UDP ', ' feature')",
#  "('respond ', ' feature')",
#  "('positive acknowledgment ', ' feature ')",
#  "('TCP ', ' feature')",
#  "('responds ', ' feature')",
#  "('incoming ', ' feature')",
#  "('UDP packet ', ' data ')",
#  "('port ', ' feature')",
#  "('closed ', ' feature')",
#  "('scan ', ' technique')",
#  "('FALSE positives ', ' feature ')",
#  ' ',
#  "('reveal ', ' feature')",
#  "('Trojan horses ', ' attack ')",
#  "('high UDP ports ', ' feature  ')",
#  "('hidden RPC services ', ' vulnerability  ')",
#  ' ',
#  "('machines ', ' system')",
#  "('slow down responses ', ' feature  ')",
#  "('traffic ', ' data')",
#  ' ',
#  "('Machines ', ' system')",
#  "('Windows OS ', ' system ')",
#  "('slowdown feature ', ' feature ')",
#  "('UDP ', ' feature')",
#  "('scan ', ' technique')",
#  "('Windows ', ' system')",
#  "('hosts ', ' system')",
#  ' ',
#  "('UDP Scan ', ' technique ')",
#  "('UDP packet ', ' data ')",
#  "('target ports ', ' feature ')",
#  "('UDP service ', ' feature ')",
#  "('listening ', ' feature')",
#  ' ',
#  "('target system ', ' system ')",
#  "('ICMP Port Unreachable message ', ' data   ')",
#  "('target port ', ' feature ')",
#  "('closed ', ' feature')",
#  "('target port ', ' feature ')",
#  "('open ', ' feature')",
#  ' ',
#  "('UDP scan ', ' technique ')",
#  "('FALSE positives ', ' feature ')",
#  ' ',
#  "('UDP scan ', ' technique ')",
#  "('slow ', ' feature')",
#  ' ',
#  "('Open ', ' feature')",
#  "('filtered ports ', ' feature ')",
#  "('send ', ' function')",
#  "('response ', ' feature')",
#  "('Nmap ', ' tool')",
#  "('time out ', ' feature ')",
#  ' ',
#  "('Closed ports ', ' feature ')",
#  "('ICMP port unreachable error ', ' data   ')",
#  "('hosts ', ' system')",
#  "('rate limit ', ' technique ')",
#  "('ICMP port unreachable messages ', ' data   ')",
#  "('default ', ' feature')",
#  ' ',
#  "('UDP scan ', ' technique ')",
#  "('host ', ' feature')",
#  "('use min-hostgroup ', ' feature ')",
#  "('scan ', ' technique')",
#  "('hosts ', ' system')",
#  ' ',
#  "('Scan ', ' technique')",
#  "('ports ', ' feature')",
#  "('scan ', ' technique')",
#  "('UDP ports ', ' feature ')",
#  ' ',
#  "('version-intensity ', ' feature')",
#  "('version detection ', ' technique ')",
#  "('scans ', ' technique')",
#  ' ',
#  "('Scan ', ' technique')",
#  "('behind the firewall ', ' feature  ')",
#  ' ',
#  "('host-timeout ', ' feature')",
#  "('slow hosts ', ' system ')",
#  ' ',
#  "('verbosity ', ' feature')",
#  "('chill out ', ' feature ')",
#  "('Nmap ', ' tool')",
#  "('scan ', ' technique')",
#  "('host ', ' system')",
#  ' ',
#  "('SYN scan ', ' technique ')",
#  "('TCP scanning ', ' technique ')",
#  ' ',
#  "('operating system�s ', ' system ')",
#  "('network functions ', ' function ')",
#  "('port scanner ', ' tool ')",
#  "('raw IP packets ', ' data  ')",
#  "('monitors ', ' technique')",
#  "('responses ', ' feature')",
#  ' ',
#  "('scan ', ' technique')",
#  "('half-open scanning ', ' technique ')",
#  "('opens ', ' feature')",
#  "('full TCP connection ', ' feature  ')",
#  ' ',
#  "('port scanner ', ' tool ')",
#  "('SYN packet ', ' data ')",
#  ' ',
#  "('target port ', ' feature ')",
#  "('open ', ' feature')",
#  "('respond ', ' feature')",
#  "('SYN-ACK packet ', ' data ')",
#  ' ',
#  "('scanner ', ' tool')",
#  "('host ', ' system')",
#  "('responds ', ' feature')",
#  "('RST packet ', ' data ')",
#  "('closing ', ' feature')",
#  "('connection ', ' feature')",
#  "('handshake ', ' technique')",
#  ' ',
#  "('port ', ' feature')",
#  "('closed ', ' feature')",
#  "('unfiltered ', ' feature')",
#  "('target ', ' system')",
#  "('respond ', ' feature')",
#  "('RST packet ', ' data ')",
#  ' ',
#  "('scan ', ' technique')",
#  "('intrusive ', ' attack')",
#  "('target host ', ' system ')",
#  ' ',
#  "('SYN scan ', ' technique ')",
#  "('services ', ' feature')",
#  "('receive ', ' function')",
#  "('connection ', ' feature')",
#  ' ',
#  "('SYN ', ' feature')",
#  "('ACK ', ' feature')",
#  "('detect ', ' technique')",
#  "('open port ', ' feature ')",
#  ' ',
#  "('SYN scans ', ' technique ')",
#  "('3-way handshake ', ' technique ')",
#  "('half-open scan ', ' technique ')",
#  ' ',
#  "('Attacker ', ' attacker')",
#  "('RESET RST ', ' feature ')",
#  "('receiving ', ' feature')",
#  "('SYN-ACK response ', ' feature ')",
#  ' ',
#  "('connection ', ' feature')",
#  "('established ', ' feature')",
#  "('target ', ' system')",
#  "('log ', ' function')",
#  "('connection ', ' feature')",
#  ' ',
#  "('stealthier ', ' vulnerability')",
#  "('full TCP Connect scans ', ' technique   ')",
#  ' ',
#  "('target port ', ' feature ')",
#  "('closed ', ' feature')",
#  "('destination ', ' system')",
#  "('RESET ', ' feature')",
#  ' ',
#  "('SYN flood ', ' attack ')",
#  "('accidental ', ' attack')",
#  "('denial-of-service attacks ', ' attack ')",
#  "('target ', ' system')",
#  "('slow ', ' feature')",
#  ' ',
#  "('FIN scan ', ' technique ')",
#  "('stealthy scan ', ' technique ')",
#  "('SYN scan ', ' technique ')",
#  "('sends ', ' function')",
#  "('TCP FIN packet ', ' data  ')",
#  ' ',
#  "('RST packet ', ' data ')",
#  "('input ', ' feature')",
#  "('FIN scan ', ' technique ')",
#  "('FALSE positives ', ' feature ')",
#  "('negatives ', ' feature')",
#  "('IDS ', ' tool')",
#  "('programs ', ' function')",
#  ' ',
#  "('Ack scanning ', ' technique ')",
#  "('port ', ' feature')",
#  "('filtered ', ' feature')",
#  ' ',
#  "('probe ', ' technique')",
#  "('firewall ', ' tool')",
#  "('rulesets ', ' function')",
#  ' ',
#  "('packet filtering ', ' technique ')",
#  "('established connections ', ' feature ')",
#  "('packets ACK bit ', ' data  ')",
#  "('stateful ', ' feature')",
#  "('firewall ', ' tool')",
#  ' ',
#  "('ACK scan ', ' technique ')",
#  "('packet ', ' data')",
#  "('ACK code bit set ', ' data   ')",
#  "('target port ', ' feature ')",
#  ' ',
#  "('attacker ', ' attacker')",
#  "('packet filtering ', ' technique ')",
#  "('devices ', ' system')",
#  ' ',
#  "('attacker ', ' attacker')",
#  "('established connections ', ' feature ')",
#  "('firewall ', ' tool')",
#  "('router ', ' system')",
#  "('network ', ' system')",
#  "('ports ', ' feature')",
#  "('firewall ', ' tool')",
#  "('established connection ', ' feature ')",
#  "('responses ', ' feature')",
#  ' ',
#  "('response ', ' feature')",
#  "('ICMP Port Unreachable message ', ' data   ')",
#  "('Nmap ', ' tool')",
#  "('target port ', ' feature ')",
#  "('filtered ', ' feature')",
#  "('packet filter ', ' technique ')",
#  "('blocking ', ' feature')",
#  "('response ', ' feature')",
#  ' ',
#  "('stealthy scan ', ' technique ')",
#  "('TCP header flags ', ' feature  ')",
#  ' ',
#  "('packet ', ' data')",
#  "('hosts ', ' system')",
#  ' ',
#  "('Windows operating systems ', ' system  ')",
#  "('scanning ', ' technique')",
#  "(' scans ', ' technique ')",
#  ' ',
#  "('non-Windows servers ', ' system ')",
#  "('firewall ', ' tool')",
#  ' ',
#  "('XMAS scan ', ' technique ')",
#  "(' scan ', ' technique ')",
#  "('flags ', ' feature')",
#  "('TCP header ', ' feature ')",
#  ' ',
#  "('Windows machines ', ' system ')",
#  "('respond ', ' feature')",
#  "('TCP stack ', ' feature ')",
#  ' ',
#  "('flags ', ' feature')",
#  "('packet ', ' data')",
#  ' ',
#  "('scans ', ' technique')",
#  "('PSH ', ' feature')",
#  "('URG ', ' feature')",
#  "('FIN flags ', ' feature ')",
#  "('TCP header ', ' feature ')",
#  ' ',
#  "('RPC scan ', ' technique ')",
#  "('scan ', ' technique')",
#  "('machines ', ' system')",
#  "('RPC ', ' function')",
#  "('Remote Procedure Call ', ' function  ')",
#  "('services ', ' app')",
#  ' ',
#  "('RPC ', ' function')",
#  "('remote commands ', ' function ')",
#  "('machine ', ' system')",
#  "('service ', ' feature')",
#  ' ',
#  "('RPC services ', ' app ')",
#  "('ports ', ' feature')",
#  "('scan ', ' technique')",
#  "('RPC ', ' function')",
#  ' ',
#  "('scan ', ' technique')",
#  "('probe ', ' technique')",
#  "('ports ', ' feature')",
#  "('open ', ' feature')",
#  "('machine ', ' system')",
#  "('commands ', ' function')",
#  "('program ', ' function')",
#  "('name ', ' feature')",
#  "('version ', ' feature')",
#  "('RPC ', ' function')",
#  ' ',
#  "('run ', ' function')",
#  "('scans ', ' technique')",
#  "('services ', ' feature')",
#  "('running ', ' function')",
#  ' ',
#  "('Scans ', ' technique')",
#  "('RPC services ', ' app ')",
#  "('open ', ' feature')",
#  "('TCP/UDP ports ', ' feature ')",
#  "('target ', ' system')",
#  "('RPC  commands ', ' function  ')",
#  ' ',
#  "('RPC ', ' function')",
#  "('program ', ' function')",
#  "('listening ', ' feature')",
#  "('port ', ' feature')",
#  "('RPC ', ' function')",
#  "('program ', ' function')",
#  ' ',
#  "('IDLE scan ', ' technique ')",
#  "('stealthy method ', ' technique ')",
#  "('scan ', ' technique')",
#  "('packets ', ' data')",
#  "('external host ', ' system ')",
#  ' ',
#  "('host ', ' system')",
#  "('requirements ', ' feature')",
#  ' ',
#  "('IP address ', ' feature ')",
#  "('zombie host ', ' system ')",
#  "('port number ', ' feature ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('malicious attacks ', ' attack ')",
#  ' ',
#  "('Probe ', ' technique')",
#  "('zombie ', ' system')",
#  "('IP ID ', ' feature ')",
#  "('Forge ', ' vulnerability')",
#  "('SYN packet ', ' data ')",
#  "('zombie ', ' system')",
#  "('port ', ' feature')",
#  "('target ', ' system')",
#  ' ',
#  "('port state ', ' feature ')",
#  "('target ', ' system')",
#  "('zombie ', ' system')",
#  "('IP ID ', ' feature ')",
#  ' ',
#  "('Probe ', ' technique')",
#  "('zombie ', ' system')",
#  "('IP ID ', ' feature ')",
#  "('target ', ' system')",
#  "('port state ', ' feature ')",
#  "('IP ID ', ' feature ')",
#  ' ',
#  "('NSE ', ' tool')",
#  "('Nmap Scripting Engine ', ' tool  ')",
#  ' ',
#  "('Nmap scripts ', ' function ')",
#  "('default ', ' feature')",
#  "('Nmap ', ' tool')",
#  "('features ', ' feature')",
#  "('Nmap ', ' tool')",
#  "('output ', ' feature')",
#  ' ',
#  "('scripts ', ' function')",
#  "('Nmap ', ' tool')",
#  "('default ', ' feature')",
#  "('NSE scripts ', ' function ')",
#  ' ',
#  "('scripts ', ' function')",
#  "('Lua programming language ', ' tool  ')",
#  ' ',
#  "('default ', ' feature')",
#  "('Nmap ', ' tool')",
#  "('target ', ' system')",
#  "('scanning ', ' technique')",
#  "('run ', ' function')",
#  ' ',
#  "('Prerule scripts ', ' function ')",
#  "('scripts ', ' function')",
#  "('scanning ', ' technique')",
#  "('Nmap ', ' tool')",
#  "('data ', ' data')",
#  "('remote target ', ' system ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('default ', ' feature')",
#  "('scan ', ' technique')",
#  "('host ', ' system')",
#  "('exploration ', ' technique')",
#  "('detection ', ' technique')",
#  "('port scanning ', ' technique ')",
#  "('software discovery ', ' technique ')",
#  "('host scripts ', ' function ')",
#  ' ',
#  "('Service scripts ', ' function ')",
#  "('Nmap scripts ', ' function ')",
#  "('run ', ' function')",
#  "('services ', ' feature')",
#  "('remote host ', ' system ')",
#  ' ',
#  "('HTTP service scripts ', ' function  ')",
#  "('run ', ' function')",
#  "('web servers ', ' system ')",
#  ' ',
#  "('Postrule scripts ', ' function ')",
#  "('run ', ' function')",
#  "('Nmap scan ', ' technique ')",
#  "('parsing ', ' function')",
#  "('formatting ', ' function')",
#  ' ',
#  "('default ', ' feature')",
#  "('Nmap scripts ', ' function ')",
#  ' ',
#  "('auth script ', ' function ')",
#  "('authentication ', ' technique')",
#  "('user privilege ', ' feature ')",
#  "('scripts ', ' function')",
#  ' ',
#  "('broadcast script ', ' function ')",
#  "('Network discovery ', ' technique ')",
#  "('scripts ', ' function')",
#  "('broadcast ', ' feature')",
#  "('intel ', ' system')",
#  ' ',
#  "('brute script ', ' function ')",
#  "('scripts ', ' function')",
#  "('brute force attacks ', ' attack  ')",
#  "('access credentials ', ' feature ')",
#  ' ',
#  "('default script ', ' function ')",
#  "('Nmap scripts ', ' function ')",
#  "('default ', ' feature')",
#  ' ',
#  "('discovery script ', ' function ')",
#  "('Scripts ', ' function')",
#  "('network discovery ', ' technique ')",
#  "('service discovery ', ' technique ')",
#  "('host discovery ', ' technique ')",
#  ' ',
#  "('dos script ', ' function ')",
#  "('Denial of service attack ', ' attack   ')",
#  "('scripts ', ' function')",
#  "('test ', ' function')",
#  "('perform ', ' function')",
#  "('DOS ', ' attack')",
#  "('floods ', ' attack')",
#  ' ',
#  "('exploit script ', ' function ')",
#  "('service exploitation ', ' technique ')",
#  "('CVEs ', ' vulnerability')",
#  ' ',
#  "('external script ', ' function ')",
#  "('Scripts ', ' function')",
#  "('3rd party services ', ' app  ')",
#  "('data ', ' data')",
#  ' ',
#  "('fuzzer script ', ' function ')",
#  "('perform ', ' function')",
#  "('fuzzing attacks ', ' attack ')",
#  "('apps ', ' app')",
#  "('services ', ' app')",
#  "('networks ', ' system')",
#  ' ',
#  "('intrusive script ', ' function ')",
#  "('aggressive� ', ' feature')",
#  "('scripts ', ' function')",
#  "('network noise ', ' feature ')",
#  ' ',
#  "('malware script ', ' function ')",
#  "('Malware detections ', ' technique ')",
#  "('exploration ', ' technique')",
#  "('scripts ', ' function')",
#  ' ',
#  "('safe script ', ' function ')",
#  "('Safe ', ' feature')",
#  "('non-intrusive ', ' feature')",
#  "('noisy ', ' feature')",
#  "('scripts ', ' function')",
#  ' ',
#  "('version script ', ' function ')",
#  "('OS ', ' system')",
#  "('service ', ' app')",
#  "('software detection ', ' technique ')",
#  "('scripts ', ' function')",
#  ' ',
#  "('vuln script ', ' function ')",
#  "('Nmap ', ' tool')",
#  "('vuln ', ' vulnerability')",
#  "('vulnerability detection ', ' technique ')",
#  "('exploitation ', ' technique')",
#  "('scripts ', ' function')",
#  ' ',
#  "('output ', ' feature')",
#  "('scanning ', ' technique')",
#  "('Metasploitable 2 host ', ' system  ')",
#  ' ',
#  "('Nmap ', ' tool')",
#  "('run ', ' function')",
#  "('scripts ', ' function')",
#  "('wildcards ', ' function')",
#  "('scripts ', ' function')",
#  ' ',
#  "('run ', ' function')",
#  "('scripts ', ' function')",
#  "('FTP� ', ' feature')",
#  "('syntax ', ' feature')",
#  ' ',
#  "('script ', ' function')",
#  ' ',
#  "('HTTP-brute script ', ' function ')",
#  "('brute force ', ' function ')",
#  "('password ', ' feature')",
#  "('auditing ', ' technique')",
#  "('HTTP basic ', ' feature ')",
#  "('digest ', ' function')",
#  "('ntlm authentication ', ' technique ')",
#  ' ',
#  "('NSE ', ' tool')",
#  "('scripts ', ' function')",
#  "('run ', ' function')",
#  "('scripts ', ' function')",
#  "('locally ', ' feature')",
#  "('operating system ', ' system ')",
#  ' ',
#  "('Firewall ', ' feature')",
#  "('Intrusion Prevention Systems IPS ', ' tool   ')",
#  "('Intrusion Detection Systems IDS ', ' tool   ')",
#  "('configure ', ' function')",
#  "('perimeter security ', ' technique ')",
#  ' ',
#  "('network ', ' system')",
#  "('Penetration Pen Testing services ', ' technique   ')",
#  "('defensive perimeter ', ' technique ')",
#  "('organization ', ' system')",
#  ' ',
#  "('IDS network security ', ' technique  ')",
#  "('IPS security ', ' technique ')",
#  "('Firewall ', ' tool')",
#  ' ',
#  "('Cyberinfrastructures ', ' system')",
#  "('prevention ', ' technique')",
#  "('platforms ', ' system')",
#  "('performance assessments ', ' technique ')",
#  "('topology ', ' feature')",
#  ' ',
#  "('assessments ', ' technique')",
#  ' ',
#  "('devices ', ' system')",
#  ' ',
#  "('static ', ' feature')",
#  "('cybercriminals ', ' attacker')",
#  "('hack ', ' attack')",
#  "('scanning ', ' technique')",
#  "('weaknesses ', ' vulnerability')",
#  ' ',
#  "('pentest ', ' technique')",
#  "('networks ', ' system')",
#  "('evading ', ' technique')",
#  "('security systems ', ' system ')",
#  ' ',
#  "('self-targeted evading activities as ', ' technique   ')",
#  "('hacking and ', ' technique ')",
#  "('as ', ' technique')",
#  '("hats\' ", \' securityTeam\')',
#  ' ',
#  "('Pentesting ', ' technique')",
#  "('attackers ', ' attacker')",
#  ' ',
#  "('blocked ', ' feature')",
#  "('portmapper ', ' tool')",
#  "('port ', ' feature')",
#  "('Nmap ', ' tool')",
#  "('RPC scanning ', ' technique ')",
#  "('bad guys ', ' attacker er')",
#  ' ',
#  "('configuring ', ' function')",
#  "('firewalls ', ' tool')",
#  "('devices ', ' system')",
#  ' ',
#  "('security holes ', ' vulnerability ')",
#  "('users ', ' user')",
#  ' ',
#  "('network scanning ', ' technique ')",
#  "('rules ', ' function')",
#  "('attackers ', ' attacker')",
#  ' ',
#  "('evading ', ' technique')",
#  "('IDS ', ' tool')",
#  "('Product evaluation ', ' technique ')",
#  ' ',
#  "('attackers ', ' attacker')",
#  "('Nmap ', ' tool')",
#  "('flag ', ' feature')",
#  "('system ', ' system')",
#  "('protection ', ' feature')",
#  ' ',
#  "('Pentesting tools ', ' tool ')",
#  "('Nmap ', ' tool')",
#  "('Metasploit ', ' tool')",
#  "('evading ', ' technique')",
#  "('firewall rules ', ' function ')",
#  "('sneaking past ', ' technique ')",
#  "('IDSs ', ' tool')",
#  ...]

# %%
#create sublists for triples
from itertools import groupby
key= entity_list.index(' ')

res = [list(sub) for ele, sub in groupby(entity_list, key = bool) if ele]
# temp_idx = entity_list.index(' ')
#res = [entity_list[: temp_idx], entity_list[temp_idx + 1: ]]

# %%
res
# Out:
# [["('Attacks ', ' attack')",
#   "('public domain ', ' system ')",
#   ' ',
#   "('IDS ', ' tool')",
#   "('Intrusion Detection ', ' technique ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Intrusion Detection ', ' technique ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('network attacks ', ' attack ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('packet logger ', ' tool ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('traffic ', ' data')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('data flow ', ' feature ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('protocol analysis ', ' technique ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('detect ', ' technique')",
#   "('attacks ', ' attack')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('packet ', ' data')",
#   "('user rules ', ' function ')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   "('language ', ' feature')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('previous ', ' feature')",
#   "('attack ', ' feature')",
#   "('pattern ', ' feature')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('network ', ' feature')",
#   "('behavior ', ' feature')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('bad packet ', ' data ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Packet Decoder ', ' tool ')",
#   ' ',
#   "('Packet Decoder ', ' tool ')",
#   "('packets ', ' data')",
#   ' ',
#   "('Packet Decoder ', ' tool ')",
#   "('protocols ', ' feature')",
#   ' ',
#   "('Packet Decoder ', ' tool ')",
#   "('packet ', ' data')",
#   "('data size ', ' feature ')",
#   ' ',
#   "('Packet Decoder ', ' tool ')",
#   "('header anomalies ', ' vulnerability ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Preprocessor ', ' tool')",
#   ' ',
#   "('Preprocessor ', ' tool')",
#   "('HTTP anomalies ', ' vulnerability ')",
#   ' ',
#   "('Preprocessor ', ' tool')",
#   "('FTP anomalies ', ' vulnerability ')",
#   ' ',
#   "('Preprocessor ', ' tool')",
#   "('packet data ', ' data ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Detection Engine ', ' tool ')",
#   ' ',
#   "('Detection Engine ', ' tool ')",
#   "('detects ', ' technique')",
#   "('intrusion ', ' attack')",
#   "('packet ', ' data')",
#   ' ',
#   "('Detection Engine ', ' tool ')",
#   "('rules ', ' function')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Log Alert system ', ' tool  ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Output Module ', ' tool ')",
#   ' ',
#   "('Output Module ', ' tool ')",
#   "('output ', ' feature')",
#   "('type ', ' feature')",
#   ' ',
#   "('Output Module ', ' tool ')",
#   "('alerts ', ' feature')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('Sniff mode ', ' feature ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('sniff ', ' technique')",
#   "('Ingress ', ' feature')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('sniff ', ' technique')",
#   "('Egress ', ' feature')",
#   ' ',
#   "('Ingress ', ' feature')",
#   "('incoming traffic ', ' data ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('sniffs ', ' technique')",
#   "('firewall traffic ', ' data ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('packet logger ', ' tool ')",
#   ' ',
#   "('packet logger ', ' tool ')",
#   "('data ', ' data')",
#   "('file ', ' data')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('tcpdump pcap ', ' data ')",
#   ' ',
#   "('Snort ', ' tool')",
#   "('unified2 ', ' tool')",
#   ' ',
#   "('Wireshark ', ' tool')",
#   "('tcpdump pcap ', ' data ')",
#   ' ',
#   "('Detection alert ', ' tool ')",
#   "('IP packets ', ' data ')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   "('icmp rules ', ' function ')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   "('system variables ', ' data ')",
#   ' ',
#   "('system variables ', ' data ')",
#   "('conf file ', ' data ')",
#   ' ',
#   "('system variables ', ' data ')",
#   "('home network ', ' system ')",
#   ' ',
#   "('system variables ', ' data ')",
#   "('external network ', ' system ')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   "('payload options ', ' feature ')",
#   ' ',
#   "('payload options ', ' feature ')",
#   "('data ', ' data')",
#   ' ',
#   "('Snort rules ', ' function ')",
#   "('non payload options ', ' feature  ')",
#   ' ',
#   "('Network ', ' system')",
#   "('client gateway server ', ' system  ')",
#   ' ',
#   "('Packet forwarding ', ' feature ')",
#   "('Gateway ', ' system')",
#   ' ',
#   "('Firewall ', ' tool')",
#   "('sniff ', ' technique')",
#   "('server ', ' system')",
#   ' ',
#   "('Firewall ', ' tool')",
#   "('testing ', ' function')",
#   ' ',
#   "('Blacklist ', ' feature')",
#   "('testing ', ' function')",
#   ' ',
#   "('Land Attack ', ' attack ')",
#   "('spoofed ', ' vulnerability')",
#   "('TCP SYN Packets ', ' data  ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('open source ', ' feature ')",
#   "('tool ', ' tool')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('network discovery ', ' technique ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('security auditing ', ' technique ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('exposed ', ' vulnerability')",
#   "('services ', ' app')",
#   "('target machine ', ' system ')",
#   "('information ', ' data')",
#   "('version ', ' technique')",
#   "('OS detection ', ' technique ')",
#   ' ',
#   "('nmap ', ' tool')",
#   "('packets ', ' data')",
#   "('network diagnostic ', ' technique ')",
#   "('testing ', ' function')",
#   ' ',
#   "('nmap ', ' tool')",
#   "('packets ', ' data')",
#   "('attacks ', ' attack')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('network mapper ', ' feature ')",
#   "('network discovery ', ' technique ')",
#   "('tools ', ' tool')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('tools ', ' tool')",
#   "('network administrators ', ' securityTeam ')",
#   "('map ', ' function')",
#   "('networks ', ' system')",
#   ' ',
#   "('program ', ' function')",
#   "('live hosts ', ' system ')",
#   "('network ', ' system')",
#   "('port scanning ', ' technique ')",
#   "('ping sweeps ', ' technique ')",
#   "('OS detection ', ' technique ')",
#   "('version detection ', ' technique ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('network scanning ', ' technique ')",
#   "('tool ', ' tool')",
#   "('IP packets ', ' data ')",
#   "('devices ', ' system')",
#   "('network ', ' system')",
#   "('information ', ' data')",
#   "('services ', ' app')",
#   "('operating systems ', ' system ')",
#   ' ',
#   "('command-line interface ', ' tool ')",
#   "('GUI front-ends ', ' tool ')",
#   ' ',
#   "('operating systems ', ' system ')",
#   "('Linux ', ' system')",
#   "('Free BSD ', ' system ')",
#   "('Gentoo ', ' system')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('enterprise-scale networks ', ' system ')",
#   "('scan ', ' function')",
#   "('connected devices ', ' system ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('IoT security ', ' technique ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('information ', ' data')",
#   "('active ', ' feature')",
#   "('IP ', ' feature')",
#   "('IP ', ' feature')",
#   "('legitimate ', ' feature')",
#   "('service ', ' app')",
#   "('external attacker ', ' attacker er')",
#   ' ',
#   "('network ', ' system')",
#   "('live hosts ', ' system ')",
#   "('open ports ', ' feature ')",
#   "('OS ', ' system')",
#   "('connected device ', ' system ')",
#   ' ',
#   "('Vulnerabilities ', ' vulnerability')",
#   "('scan ', ' function')",
#   "('server ', ' system')",
#   "('process ', ' technique')",
#   "('hacker ', ' attacker')",
#   "('attack ', ' attack')",
#   "('site ', ' system')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('processes ', ' technique')",
#   ' ',
#   "('information ', ' data')",
#   "('IP ', ' feature')",
#   "('active ', ' feature')",
#   "('networks ', ' system')",
#   "('IP ', ' feature')",
#   "('scanned ', ' function')",
#   ' ',
#   "('administrators ', ' securityTeam')",
#   "('IP ', ' feature')",
#   "('legitimate service ', ' feature ')",
#   "('external attacker ', ' attacker er')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('information ', ' data')",
#   "('network ', ' system')",
#   ' ',
#   "('live hosts ', ' system ')",
#   "('open ports ', ' feature ')",
#   "('OS ', ' system')",
#   "('connected device ', ' system ')",
#   ' ',
#   "('tool ', ' tool')",
#   "('system monitoring ', ' technique ')",
#   "('pentesting ', ' technique')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('Metasploit framework ', ' tool ')",
#   "('probe ', ' technique')",
#   "('network vulnerabilities ', ' vulnerability ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('tool ', ' tool')",
#   "('users ', ' user')",
#   "('personal ', ' system')",
#   "('business websites ', ' system ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('scan ', ' technique')",
#   "('web server ', ' system ')",
#   "('hosting ', ' feature')",
#   "('website ', ' system')",
#   "('home ', ' system')",
#   "('hacker ', ' attacker')",
#   "('process ', ' technique')",
#   "('attack ', ' attack')",
#   "('site ', ' system')",
#   ' ',
#   "('Attacking ', ' attack')",
#   "('site ', ' system')",
#   "('security vulnerabilities ', ' vulnerability ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('tools ', ' tool')",
#   "('system admins ', ' securityTeam ')",
#   "('programs ', ' function')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('tools ', ' tool')",
#   "('program ', ' function')",
#   "('network monitoring ', ' technique ')",
#   "('tools ', ' tool')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('command-line interfaces ', ' tool ')",
#   ' ',
#   "('users ', ' user')",
#   "('scripts ', ' function')",
#   "('automate ', ' feature')",
#   "('network monitoring ', ' technique ')",
#   ' ',
#   "('TCP Full Connect Vanilla Scan ', ' technique    ')",
#   ' ',
#   "('scanning ', ' technique')",
#   "('target�s ', ' system')",
#   "('IP address ', ' feature ')",
#   ' ',
#   "('TCP Connect scan ', ' technique  ')",
#   "('3-way handshake ', ' technique ')",
#   ' ',
#   "('port ', ' feature')",
#   "('open ', ' feature')",
#   "('operating system ', ' system ')",
#   "('TCP ', ' feature')",
#   "('three-way handshake ', ' technique ')",
#   "('port scanner ', ' tool ')",
#   "('connection ', ' feature')",
#   "('DOS ', ' attack')",
#   ' ',
#   "('noisy ', ' feature')",
#   "('services ', ' feature')",
#   "('log ', ' function')",
#   "('sender ', ' system')",
#   "('IP address ', ' feature ')",
#   "('Intrusion Detection Systems ', ' tool  ')",
#   ' ',
#   "('Full scan ', ' technique ')",
#   ' ',
#   "('3-way handshake ', ' technique ')",
#   "('scanned ', ' vulnerability')",
#   "('port ', ' feature')",
#   ' ',
#   "('Sends ', ' function')",
#   "('SYN ', ' feature')",
#   "('ACK ', ' feature')",
#   "('sending ', ' function')",
#   "('ACK ', ' feature')",
#   ' ',
#   "('Tears down ', ' feature ')",
#   "('connection ', ' feature')",
#   "('FIN packets ', ' data ')",
#   ' ',
#   "('target port ', ' feature ')",
#   "('closed ', ' feature')",
#   "('sender ', ' system')",
#   "('received ', ' function')",
#   "('response ', ' feature')",
#   "('RESET packet ', ' data ')",
#   "('ICMP Port Unreachable packet ', ' data   ')",
#   ' ',
#   "('stealthy ', ' vulnerability')",
#   "('connection request ', ' feature ')",
#   "('logged ', ' function')",
#   ' ',
#   "('UDP scan ', ' technique ')",
#   "('UDP ports ', ' feature ')",
#   "('listening ', ' feature')",
#   ' ',
#   "('UDP ', ' feature')",
#   "('respond ', ' feature')",
#   "('positive acknowledgment ', ' feature ')",
#   "('TCP ', ' feature')",
#   "('responds ', ' feature')",
#   "('incoming ', ' feature')",
#   "('UDP packet ', ' data ')",
#   "('port ', ' feature')",
#   "('closed ', ' feature')",
#   "('scan ', ' technique')",
#   "('FALSE positives ', ' feature ')",
#   ' ',
#   "('reveal ', ' feature')",
#   "('Trojan horses ', ' attack ')",
#   "('high UDP ports ', ' feature  ')",
#   "('hidden RPC services ', ' vulnerability  ')",
#   ' ',
#   "('machines ', ' system')",
#   "('slow down responses ', ' feature  ')",
#   "('traffic ', ' data')",
#   ' ',
#   "('Machines ', ' system')",
#   "('Windows OS ', ' system ')",
#   "('slowdown feature ', ' feature ')",
#   "('UDP ', ' feature')",
#   "('scan ', ' technique')",
#   "('Windows ', ' system')",
#   "('hosts ', ' system')",
#   ' ',
#   "('UDP Scan ', ' technique ')",
#   "('UDP packet ', ' data ')",
#   "('target ports ', ' feature ')",
#   "('UDP service ', ' feature ')",
#   "('listening ', ' feature')",
#   ' ',
#   "('target system ', ' system ')",
#   "('ICMP Port Unreachable message ', ' data   ')",
#   "('target port ', ' feature ')",
#   "('closed ', ' feature')",
#   "('target port ', ' feature ')",
#   "('open ', ' feature')",
#   ' ',
#   "('UDP scan ', ' technique ')",
#   "('FALSE positives ', ' feature ')",
#   ' ',
#   "('UDP scan ', ' technique ')",
#   "('slow ', ' feature')",
#   ' ',
#   "('Open ', ' feature')",
#   "('filtered ports ', ' feature ')",
#   "('send ', ' function')",
#   "('response ', ' feature')",
#   "('Nmap ', ' tool')",
#   "('time out ', ' feature ')",
#   ' ',
#   "('Closed ports ', ' feature ')",
#   "('ICMP port unreachable error ', ' data   ')",
#   "('hosts ', ' system')",
#   "('rate limit ', ' technique ')",
#   "('ICMP port unreachable messages ', ' data   ')",
#   "('default ', ' feature')",
#   ' ',
#   "('UDP scan ', ' technique ')",
#   "('host ', ' feature')",
#   "('use min-hostgroup ', ' feature ')",
#   "('scan ', ' technique')",
#   "('hosts ', ' system')",
#   ' ',
#   "('Scan ', ' technique')",
#   "('ports ', ' feature')",
#   "('scan ', ' technique')",
#   "('UDP ports ', ' feature ')",
#   ' ',
#   "('version-intensity ', ' feature')",
#   "('version detection ', ' technique ')",
#   "('scans ', ' technique')",
#   ' ',
#   "('Scan ', ' technique')",
#   "('behind the firewall ', ' feature  ')",
#   ' ',
#   "('host-timeout ', ' feature')",
#   "('slow hosts ', ' system ')",
#   ' ',
#   "('verbosity ', ' feature')",
#   "('chill out ', ' feature ')",
#   "('Nmap ', ' tool')",
#   "('scan ', ' technique')",
#   "('host ', ' system')",
#   ' ',
#   "('SYN scan ', ' technique ')",
#   "('TCP scanning ', ' technique ')",
#   ' ',
#   "('operating system�s ', ' system ')",
#   "('network functions ', ' function ')",
#   "('port scanner ', ' tool ')",
#   "('raw IP packets ', ' data  ')",
#   "('monitors ', ' technique')",
#   "('responses ', ' feature')",
#   ' ',
#   "('scan ', ' technique')",
#   "('half-open scanning ', ' technique ')",
#   "('opens ', ' feature')",
#   "('full TCP connection ', ' feature  ')",
#   ' ',
#   "('port scanner ', ' tool ')",
#   "('SYN packet ', ' data ')",
#   ' ',
#   "('target port ', ' feature ')",
#   "('open ', ' feature')",
#   "('respond ', ' feature')",
#   "('SYN-ACK packet ', ' data ')",
#   ' ',
#   "('scanner ', ' tool')",
#   "('host ', ' system')",
#   "('responds ', ' feature')",
#   "('RST packet ', ' data ')",
#   "('closing ', ' feature')",
#   "('connection ', ' feature')",
#   "('handshake ', ' technique')",
#   ' ',
#   "('port ', ' feature')",
#   "('closed ', ' feature')",
#   "('unfiltered ', ' feature')",
#   "('target ', ' system')",
#   "('respond ', ' feature')",
#   "('RST packet ', ' data ')",
#   ' ',
#   "('scan ', ' technique')",
#   "('intrusive ', ' attack')",
#   "('target host ', ' system ')",
#   ' ',
#   "('SYN scan ', ' technique ')",
#   "('services ', ' feature')",
#   "('receive ', ' function')",
#   "('connection ', ' feature')",
#   ' ',
#   "('SYN ', ' feature')",
#   "('ACK ', ' feature')",
#   "('detect ', ' technique')",
#   "('open port ', ' feature ')",
#   ' ',
#   "('SYN scans ', ' technique ')",
#   "('3-way handshake ', ' technique ')",
#   "('half-open scan ', ' technique ')",
#   ' ',
#   "('Attacker ', ' attacker')",
#   "('RESET RST ', ' feature ')",
#   "('receiving ', ' feature')",
#   "('SYN-ACK response ', ' feature ')",
#   ' ',
#   "('connection ', ' feature')",
#   "('established ', ' feature')",
#   "('target ', ' system')",
#   "('log ', ' function')",
#   "('connection ', ' feature')",
#   ' ',
#   "('stealthier ', ' vulnerability')",
#   "('full TCP Connect scans ', ' technique   ')",
#   ' ',
#   "('target port ', ' feature ')",
#   "('closed ', ' feature')",
#   "('destination ', ' system')",
#   "('RESET ', ' feature')",
#   ' ',
#   "('SYN flood ', ' attack ')",
#   "('accidental ', ' attack')",
#   "('denial-of-service attacks ', ' attack ')",
#   "('target ', ' system')",
#   "('slow ', ' feature')",
#   ' ',
#   "('FIN scan ', ' technique ')",
#   "('stealthy scan ', ' technique ')",
#   "('SYN scan ', ' technique ')",
#   "('sends ', ' function')",
#   "('TCP FIN packet ', ' data  ')",
#   ' ',
#   "('RST packet ', ' data ')",
#   "('input ', ' feature')",
#   "('FIN scan ', ' technique ')",
#   "('FALSE positives ', ' feature ')",
#   "('negatives ', ' feature')",
#   "('IDS ', ' tool')",
#   "('programs ', ' function')",
#   ' ',
#   "('Ack scanning ', ' technique ')",
#   "('port ', ' feature')",
#   "('filtered ', ' feature')",
#   ' ',
#   "('probe ', ' technique')",
#   "('firewall ', ' tool')",
#   "('rulesets ', ' function')",
#   ' ',
#   "('packet filtering ', ' technique ')",
#   "('established connections ', ' feature ')",
#   "('packets ACK bit ', ' data  ')",
#   "('stateful ', ' feature')",
#   "('firewall ', ' tool')",
#   ' ',
#   "('ACK scan ', ' technique ')",
#   "('packet ', ' data')",
#   "('ACK code bit set ', ' data   ')",
#   "('target port ', ' feature ')",
#   ' ',
#   "('attacker ', ' attacker')",
#   "('packet filtering ', ' technique ')",
#   "('devices ', ' system')",
#   ' ',
#   "('attacker ', ' attacker')",
#   "('established connections ', ' feature ')",
#   "('firewall ', ' tool')",
#   "('router ', ' system')",
#   "('network ', ' system')",
#   "('ports ', ' feature')",
#   "('firewall ', ' tool')",
#   "('established connection ', ' feature ')",
#   "('responses ', ' feature')",
#   ' ',
#   "('response ', ' feature')",
#   "('ICMP Port Unreachable message ', ' data   ')",
#   "('Nmap ', ' tool')",
#   "('target port ', ' feature ')",
#   "('filtered ', ' feature')",
#   "('packet filter ', ' technique ')",
#   "('blocking ', ' feature')",
#   "('response ', ' feature')",
#   ' ',
#   "('stealthy scan ', ' technique ')",
#   "('TCP header flags ', ' feature  ')",
#   ' ',
#   "('packet ', ' data')",
#   "('hosts ', ' system')",
#   ' ',
#   "('Windows operating systems ', ' system  ')",
#   "('scanning ', ' technique')",
#   "(' scans ', ' technique ')",
#   ' ',
#   "('non-Windows servers ', ' system ')",
#   "('firewall ', ' tool')",
#   ' ',
#   "('XMAS scan ', ' technique ')",
#   "(' scan ', ' technique ')",
#   "('flags ', ' feature')",
#   "('TCP header ', ' feature ')",
#   ' ',
#   "('Windows machines ', ' system ')",
#   "('respond ', ' feature')",
#   "('TCP stack ', ' feature ')",
#   ' ',
#   "('flags ', ' feature')",
#   "('packet ', ' data')",
#   ' ',
#   "('scans ', ' technique')",
#   "('PSH ', ' feature')",
#   "('URG ', ' feature')",
#   "('FIN flags ', ' feature ')",
#   "('TCP header ', ' feature ')",
#   ' ',
#   "('RPC scan ', ' technique ')",
#   "('scan ', ' technique')",
#   "('machines ', ' system')",
#   "('RPC ', ' function')",
#   "('Remote Procedure Call ', ' function  ')",
#   "('services ', ' app')",
#   ' ',
#   "('RPC ', ' function')",
#   "('remote commands ', ' function ')",
#   "('machine ', ' system')",
#   "('service ', ' feature')",
#   ' ',
#   "('RPC services ', ' app ')",
#   "('ports ', ' feature')",
#   "('scan ', ' technique')",
#   "('RPC ', ' function')",
#   ' ',
#   "('scan ', ' technique')",
#   "('probe ', ' technique')",
#   "('ports ', ' feature')",
#   "('open ', ' feature')",
#   "('machine ', ' system')",
#   "('commands ', ' function')",
#   "('program ', ' function')",
#   "('name ', ' feature')",
#   "('version ', ' feature')",
#   "('RPC ', ' function')",
#   ' ',
#   "('run ', ' function')",
#   "('scans ', ' technique')",
#   "('services ', ' feature')",
#   "('running ', ' function')",
#   ' ',
#   "('Scans ', ' technique')",
#   "('RPC services ', ' app ')",
#   "('open ', ' feature')",
#   "('TCP/UDP ports ', ' feature ')",
#   "('target ', ' system')",
#   "('RPC  commands ', ' function  ')",
#   ' ',
#   "('RPC ', ' function')",
#   "('program ', ' function')",
#   "('listening ', ' feature')",
#   "('port ', ' feature')",
#   "('RPC ', ' function')",
#   "('program ', ' function')",
#   ' ',
#   "('IDLE scan ', ' technique ')",
#   "('stealthy method ', ' technique ')",
#   "('scan ', ' technique')",
#   "('packets ', ' data')",
#   "('external host ', ' system ')",
#   ' ',
#   "('host ', ' system')",
#   "('requirements ', ' feature')",
#   ' ',
#   "('IP address ', ' feature ')",
#   "('zombie host ', ' system ')",
#   "('port number ', ' feature ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('malicious attacks ', ' attack ')",
#   ' ',
#   "('Probe ', ' technique')",
#   "('zombie ', ' system')",
#   "('IP ID ', ' feature ')",
#   "('Forge ', ' vulnerability')",
#   "('SYN packet ', ' data ')",
#   "('zombie ', ' system')",
#   "('port ', ' feature')",
#   "('target ', ' system')",
#   ' ',
#   "('port state ', ' feature ')",
#   "('target ', ' system')",
#   "('zombie ', ' system')",
#   "('IP ID ', ' feature ')",
#   ' ',
#   "('Probe ', ' technique')",
#   "('zombie ', ' system')",
#   "('IP ID ', ' feature ')",
#   "('target ', ' system')",
#   "('port state ', ' feature ')",
#   "('IP ID ', ' feature ')",
#   ' ',
#   "('NSE ', ' tool')",
#   "('Nmap Scripting Engine ', ' tool  ')",
#   ' ',
#   "('Nmap scripts ', ' function ')",
#   "('default ', ' feature')",
#   "('Nmap ', ' tool')",
#   "('features ', ' feature')",
#   "('Nmap ', ' tool')",
#   "('output ', ' feature')",
#   ' ',
#   "('scripts ', ' function')",
#   "('Nmap ', ' tool')",
#   "('default ', ' feature')",
#   "('NSE scripts ', ' function ')",
#   ' ',
#   "('scripts ', ' function')",
#   "('Lua programming language ', ' tool  ')",
#   ' ',
#   "('default ', ' feature')",
#   "('Nmap ', ' tool')",
#   "('target ', ' system')",
#   "('scanning ', ' technique')",
#   "('run ', ' function')",
#   ' ',
#   "('Prerule scripts ', ' function ')",
#   "('scripts ', ' function')",
#   "('scanning ', ' technique')",
#   "('Nmap ', ' tool')",
#   "('data ', ' data')",
#   "('remote target ', ' system ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('default ', ' feature')",
#   "('scan ', ' technique')",
#   "('host ', ' system')",
#   "('exploration ', ' technique')",
#   "('detection ', ' technique')",
#   "('port scanning ', ' technique ')",
#   "('software discovery ', ' technique ')",
#   "('host scripts ', ' function ')",
#   ' ',
#   "('Service scripts ', ' function ')",
#   "('Nmap scripts ', ' function ')",
#   "('run ', ' function')",
#   "('services ', ' feature')",
#   "('remote host ', ' system ')",
#   ' ',
#   "('HTTP service scripts ', ' function  ')",
#   "('run ', ' function')",
#   "('web servers ', ' system ')",
#   ' ',
#   "('Postrule scripts ', ' function ')",
#   "('run ', ' function')",
#   "('Nmap scan ', ' technique ')",
#   "('parsing ', ' function')",
#   "('formatting ', ' function')",
#   ' ',
#   "('default ', ' feature')",
#   "('Nmap scripts ', ' function ')",
#   ' ',
#   "('auth script ', ' function ')",
#   "('authentication ', ' technique')",
#   "('user privilege ', ' feature ')",
#   "('scripts ', ' function')",
#   ' ',
#   "('broadcast script ', ' function ')",
#   "('Network discovery ', ' technique ')",
#   "('scripts ', ' function')",
#   "('broadcast ', ' feature')",
#   "('intel ', ' system')",
#   ' ',
#   "('brute script ', ' function ')",
#   "('scripts ', ' function')",
#   "('brute force attacks ', ' attack  ')",
#   "('access credentials ', ' feature ')",
#   ' ',
#   "('default script ', ' function ')",
#   "('Nmap scripts ', ' function ')",
#   "('default ', ' feature')",
#   ' ',
#   "('discovery script ', ' function ')",
#   "('Scripts ', ' function')",
#   "('network discovery ', ' technique ')",
#   "('service discovery ', ' technique ')",
#   "('host discovery ', ' technique ')",
#   ' ',
#   "('dos script ', ' function ')",
#   "('Denial of service attack ', ' attack   ')",
#   "('scripts ', ' function')",
#   "('test ', ' function')",
#   "('perform ', ' function')",
#   "('DOS ', ' attack')",
#   "('floods ', ' attack')",
#   ' ',
#   "('exploit script ', ' function ')",
#   "('service exploitation ', ' technique ')",
#   "('CVEs ', ' vulnerability')",
#   ' ',
#   "('external script ', ' function ')",
#   "('Scripts ', ' function')",
#   "('3rd party services ', ' app  ')",
#   "('data ', ' data')",
#   ' ',
#   "('fuzzer script ', ' function ')",
#   "('perform ', ' function')",
#   "('fuzzing attacks ', ' attack ')",
#   "('apps ', ' app')",
#   "('services ', ' app')",
#   "('networks ', ' system')",
#   ' ',
#   "('intrusive script ', ' function ')",
#   "('aggressive� ', ' feature')",
#   "('scripts ', ' function')",
#   "('network noise ', ' feature ')",
#   ' ',
#   "('malware script ', ' function ')",
#   "('Malware detections ', ' technique ')",
#   "('exploration ', ' technique')",
#   "('scripts ', ' function')",
#   ' ',
#   "('safe script ', ' function ')",
#   "('Safe ', ' feature')",
#   "('non-intrusive ', ' feature')",
#   "('noisy ', ' feature')",
#   "('scripts ', ' function')",
#   ' ',
#   "('version script ', ' function ')",
#   "('OS ', ' system')",
#   "('service ', ' app')",
#   "('software detection ', ' technique ')",
#   "('scripts ', ' function')",
#   ' ',
#   "('vuln script ', ' function ')",
#   "('Nmap ', ' tool')",
#   "('vuln ', ' vulnerability')",
#   "('vulnerability detection ', ' technique ')",
#   "('exploitation ', ' technique')",
#   "('scripts ', ' function')",
#   ' ',
#   "('output ', ' feature')",
#   "('scanning ', ' technique')",
#   "('Metasploitable 2 host ', ' system  ')",
#   ' ',
#   "('Nmap ', ' tool')",
#   "('run ', ' function')",
#   "('scripts ', ' function')",
#   "('wildcards ', ' function')",
#   "('scripts ', ' function')",
#   ' ',
#   "('run ', ' function')",
#   "('scripts ', ' function')",
#   "('FTP� ', ' feature')",
#   "('syntax ', ' feature')",
#   ' ',
#   "('script ', ' function')",
#   ' ',
#   "('HTTP-brute script ', ' function ')",
#   "('brute force ', ' function ')",
#   "('password ', ' feature')",
#   "('auditing ', ' technique')",
#   "('HTTP basic ', ' feature ')",
#   "('digest ', ' function')",
#   "('ntlm authentication ', ' technique ')",
#   ' ',
#   "('NSE ', ' tool')",
#   "('scripts ', ' function')",
#   "('run ', ' function')",
#   "('scripts ', ' function')",
#   "('locally ', ' feature')",
#   "('operating system ', ' system ')",
#   ' ',
#   "('Firewall ', ' feature')",
#   "('Intrusion Prevention Systems IPS ', ' tool   ')",
#   "('Intrusion Detection Systems IDS ', ' tool   ')",
#   "('configure ', ' function')",
#   "('perimeter security ', ' technique ')",
#   ' ',
#   "('network ', ' system')",
#   "('Penetration Pen Testing services ', ' technique   ')",
#   "('defensive perimeter ', ' technique ')",
#   "('organization ', ' system')",
#   ' ',
#   "('IDS network security ', ' technique  ')",
#   "('IPS security ', ' technique ')",
#   "('Firewall ', ' tool')",
#   ' ',
#   "('Cyberinfrastructures ', ' system')",
#   "('prevention ', ' technique')",
#   "('platforms ', ' system')",
#   "('performance assessments ', ' technique ')",
#   "('topology ', ' feature')",
#   ' ',
#   "('assessments ', ' technique')",
#   ' ',
#   "('devices ', ' system')",
#   ' ',
#   "('static ', ' feature')",
#   "('cybercriminals ', ' attacker')",
#   "('hack ', ' attack')",
#   "('scanning ', ' technique')",
#   "('weaknesses ', ' vulnerability')",
#   ' ',
#   "('pentest ', ' technique')",
#   "('networks ', ' system')",
#   "('evading ', ' technique')",
#   "('security systems ', ' system ')",
#   ' ',
#   "('self-targeted evading activities as ', ' technique   ')",
#   "('hacking and ', ' technique ')",
#   "('as ', ' technique')",
#   '("hats\' ", \' securityTeam\')',
#   ' ',
#   "('Pentesting ', ' technique')",
#   "('attackers ', ' attacker')",
#   ' ',
#   "('blocked ', ' feature')",
#   "('portmapper ', ' tool')",
#   "('port ', ' feature')",
#   "('Nmap ', ' tool')",
#   "('RPC scanning ', ' technique ')",
#   "('bad guys ', ' attacker er')",
#   ' ',
#   "('configuring ', ' function')",
#   "('firewalls ', ' tool')",
#   "('devices ', ' system')",
#   ' ',
#   "('security holes ', ' vulnerability ')",
#   "('users ', ' user')",
#   ' ',
#   "('network scanning ', ' technique ')",
#   "('rules ', ' function')",
#   "('attackers ', ' attacker')",
#   ' ',
#   "('evading ', ' technique')",
#   "('IDS ', ' tool')",
#   "('Product evaluation ', ' technique ')",
#   ' ',
#   "('attackers ', ' attacker')",
#   "('Nmap ', ' tool')",
#   "('flag ', ' feature')",
#   "('system ', ' system')",
#   "('protection ', ' feature')",
#   ' ',
#   "('Pentesting tools ', ' tool ')",
#   "('Nmap ', ' tool')",
#   "('Metasploit ', ' tool')",
#   "('evading ', ' technique')",
#   "('firewall rules ', ' function ')",
#   "('sneaking past ', ' technique ')",
#   "('IDSs ', ' tool')",
#   ...]]
